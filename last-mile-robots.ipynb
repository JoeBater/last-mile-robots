# %% [markdown]
# # Last mile robots

# %%
# libraries are always a good place to start
import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt
import seaborn as sns

from Battery import Battery
from DeliveryRobot import DeliveryRobot

from Task import Task

# %%
possible_cities = pd.read_csv(r'last-mile-cities.csv')
possible_cities
# Out:
#             city
# 0        Glasgow
# 1          Leeds
# 2      Liverpool
# 3      Newcastle
# 4        Belfast
# 5      Inverness
# 6       Carlisle
# 7      Lancaster
# 8          Derry
# 9        Wrexham
# 10        London
# 11    Birmingham
# 12       Bristol
# 13   Southampton
# 14       Cardiff
# 15     Cambridge
# 16      Plymouth
# 17          Bath
# 18    Chichester
# 19  Aberwystwyth

# %%
# choose a city
city = 'Cambridge'
solomon_instance = 'r101'

# get instance and weather file
instance_file = 'C:/Users/user/ML/Optimisation/VRPTW/solomon/augmented/' + city + '_2.5_' + solomon_instance + '.csv'
weather_file = 'C:/Users/user/ML/Optimisation/VRPTW/weather_data/open-meteo/' + city+'-weather.csv'

# get the locations and clean
locations = pd.read_csv(instance_file, usecols=['xcoord.','ycoord.','elevation'])
locations.columns = ['x', 'y', 'elevation']

city+'-weather.csv'
locations['x'] = locations['x']*25
locations['y'] = locations['y']*25
locations['elevation'] = np.round(locations['elevation'], 2)

print(np.max(locations['x']), np.max(locations['y']), np.min(locations['x']), np.min(locations['y']))

locations
# Out:
# 1675 1925 50 75
#         x     y  elevation
# 0     875   875      15.65
# 1    1025  1225      16.84
# 2     875   425      15.30
# 3    1375  1125      18.95
# 4    1375   500      18.71
# ..    ...   ...        ...
# 96    550   675      15.25
# 97    625   525      16.80
# 98    475   525      13.59
# 99    500   650      14.44
# 100   450   450      14.05
#
# [101 rows x 3 columns]

# %%
# read the weather data
weather = pd.read_csv(weather_file)
weather = weather.drop(['date', 'dew_point_2m', 'wind_direction_10m', 'wind_gusts_10m', 'is_day'], axis=1)

weather['day'] = weather['day'].astype(int)
weather['month'] = weather['month'].astype(int)
weather['hour'] = weather['hour'].astype(int)

weather.dtypes
# Out:
# temperature_2m    float64
# rain              float64
# wind_speed_10m    float64
# month               int32
# day                 int32
# hour                int32
# dtype: object

# %%
def plot_weather_data(weather):
    import matplotlib.dates as mdates

    weather['Year'] = 2026  # Arbitrary fixed year
    weather['Date'] = pd.to_datetime(weather[['day', 'month', 'Year']], dayfirst=True)

    month_names = {
        1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',
        5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug',
        9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'
    }

    plt.figure(figsize=(20, 15))

    for month in range(1, 13):
        ax = plt.subplot(4, 3, month)
        month_data = weather[weather['Month'] == month]

        # Bar plot for rain first (in the background)
        ax.bar(month_data['Date'], month_data['rain_mm'], 
               width=1.0, label='Rain (mm)', color='skyblue', alpha=0.5)

        # Line for temperature (in the foreground)
        ax.plot(month_data['Date'], month_data['temperature_2m'], 
                label='Avg Temp (°C)', color='orange', linewidth=2)

        # Optional: uncomment to include wind speed too
        ax.plot(month_data['Date'], month_data['wind_speed_10m'], 
                label='Wind Speed (m/s)', color='green', linestyle='--')

        ax.set_title(f'Month: {month_names[month]}')
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%b'))
        ax.tick_params(axis='x', rotation=45)
        ax.set_ylabel('Values')
        ax.legend()

    plt.tight_layout()
    plt.show()

# Call the function to plot the weather data
plot_weather_data(weather)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\tools\datetimes.py:1259, in _assemble_from_unit_mappings(arg, errors, utc)
#    1258 try:
# -> 1259     values = to_datetime(values, format="%Y%m%d", errors=errors, utc=utc)
#    1260 except (TypeError, ValueError) as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\tools\datetimes.py:1108, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1107 elif isinstance(arg, ABCSeries):
# -> 1108     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1109     if not cache_array.empty:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\tools\datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     253 if len(unique_dates) < len(arg):
# --> 254     cache_dates = convert_listlike(unique_dates, format)
#     255     # GH#45319
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\tools\datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     516 """
#     517 Call array_strptime, with fallback behavior depending on 'errors'.
#     518 """
# --> 519 result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520 if any(tz is not None for tz in timezones):
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:493, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: day is out of range for month, at position 59. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 41
#      38     plt.show()
#      40 # Call the function to plot the weather data
# ---> 41 plot_weather_data(weather)
#
# Cell In[53], line 5, in plot_weather_data(weather)
#       2 import matplotlib.dates as mdates
#       4 weather['Year'] = 2026  # Arbitrary fixed year
# ----> 5 weather['Date'] = pd.to_datetime(weather[['day', 'month', 'Year']], dayfirst=True)
#       7 month_names = {
#       8     1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',
#       9     5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug',
#      10     9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'
#      11 }
#      13 plt.figure(figsize=(20, 15))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\tools\datetimes.py:1115, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1115     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1116 elif isinstance(arg, Index):
#    1117     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\tools\datetimes.py:1261, in _assemble_from_unit_mappings(arg, errors, utc)
#    1259     values = to_datetime(values, format="%Y%m%d", errors=errors, utc=utc)
#    1260 except (TypeError, ValueError) as err:
# -> 1261     raise ValueError(f"cannot assemble the datetimes: {err}") from err
#    1263 units: list[UnitChoices] = ["h", "m", "s", "ms", "us", "ns"]
#    1264 for u in units:
#
# ValueError: cannot assemble the datetimes: day is out of range for month, at position 59. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
print(weather.iloc[59][['day', 'month', 'Year']])
print(weather.iloc[59])
# Out:
# day         3.0
# month       1.0
# Year     2026.0
# Name: 59, dtype: float64
# temperature_2m       9.6520
# rain                 0.0000
# wind_speed_10m      23.0653
# month                1.0000
# day                  3.0000
# hour                11.0000
# Year              2026.0000
# Name: 59, dtype: float64

# %%
# build a randomised customer order dataframe
orders = pd.DataFrame(columns=['ID', 'city', 'month', 'day', 'hour', 'minute', 'prep_time', 'customer', 'status'])

order_id = 0
day_of_year = 0

def generate_order_time(time_block=None):
    if time_block == 'morning':
        hour = np.random.randint(9, 12)
    elif time_block == 'lunch':
        hour = np.random.randint(12, 15)
    elif time_block == 'afternoon':
        hour = np.random.randint(15, 18)
    elif time_block == 'evening':
        hour = np.random.randint(18, 21)
    else:
        hour = np.random.randint(9, 21)
    minute = (np.random.randint(0, 12) * 5)  # gives 5 minute intervals
    return hour, minute

# AND NOW FOR THE FUN PART - GENERATING ORDERS :-)
for m in range(1,13):

    # use weather data to determine the day of the week number of days in the month
    weather_month = weather[weather['Month'] == m]
    days_in_month = weather_month['Day'].max()

    for d in range(1, days_in_month + 1):

        # what is the day of the week - assuming Jan 1st is a Monday - determine the base order probability
        day_of_week = day_of_year % 7
        if day_of_week < 5:     # weekday
            order_prob = 0.15
        elif day_of_week == 5:  # saturday
            order_prob = 0.15 * 1.2
        elif day_of_week == 6:  # sunday
            order_prob = 0.15 * 0.8

        # what is the average temperature for the day
        weather_day = weather_month[weather_month['Day'] == d]
        avg_temp = weather_day['DryBulbTemperature_C'].mean()
        avg_rain = weather_day['synthetic_rain_mm'].mean()

        if avg_temp < 10:
            # cold day
            if avg_rain > 0:
                # rainy day
                order_prob *= 1.2
            else:
                # dry day - but still reluctant to go out
                order_prob *= 1.1
            
        elif avg_temp < 20:
            # mild day
            if avg_rain > 0:
                # rainy day - mild and wet is unpleasant
                order_prob *= 1.1
            else:
                # dry day
                order_prob *= 1.0
            
        elif avg_temp < 30:
            # warm day
            if avg_rain > 0:
                # rainy day
                order_prob *= 1.0
            else:
                # dry day - might actually enjoy going out
                order_prob *= 0.95

        else:
            # hot day
            if avg_rain > 0:
                # rainy day
                order_prob *= 1.0
            else:
                # dry day - brutal heat
                order_prob *= 1.3


        # look to each location
        for i in range(1, 101):

            # weekday orders tend to follow a distribution with peaks at lunch and dinner times
            if day_of_week < 5:
                    
                # with probability 0.15, create a random order - (in a real-world scenario, this would be replaced with actual order data) - from a database or API
                if np.random.rand() < order_prob:
                
                    order_seed = np.random.rand() * 5.5
                    if order_seed < 1:
                        # morning orders are placed at random times between 8am and 10am
                        time_block = 'morning'
                    elif order_seed < 2.5:
                        # lunch orders are placed at random times between 12pm and 2pm
                        time_block = 'lunch'
                    elif order_seed < 3.5:
                        # afternoon orders are placed at random times between 3pm and 5pm
                        time_block = 'afternoon'
                    else:
                        # evening orders are placed at random times between 6pm and 8pm
                        time_block = 'evening'
            
                    order_hour, order_minute = generate_order_time(time_block)
                    order = pd.DataFrame({
                        'ID': order_id,
                        'city' : city,
                        'month' : m,
                        'day': d,
                        'hour': order_hour,
                        'minute': order_minute,
                        'prep_time': np.random.choice([1,5,10,15]),  # random prep time between 1 and 15 minutes
                        'customer': i,
                        'status': 'open'
                    }, index=[0])
                    order_id += 1
                    orders = pd.concat([orders, order], ignore_index=True)

            elif day_of_week == 5:
                # saturdays are busier
                if np.random.rand() < order_prob:
                    
                    order_hour, order_minute = generate_order_time()
                    order = pd.DataFrame({
                        'ID': order_id,
                        'city' : city,
                        'month' : m,
                        'day': d,
                        'hour': order_hour,
                        'minute': order_minute,
                        'prep_time': np.random.choice([1,5,10,15]),  # random prep time between 1 and 15 minutes
                        'customer': i,
                        'status': 'open'
                    }, index=[0])
                    order_id += 1
                    orders = pd.concat([orders, order], ignore_index=True)
                
            elif day_of_week == 6:
                # sundays are less busy
                if np.random.rand() < order_prob:
                    order_hour, order_minute = generate_order_time()
                    order = pd.DataFrame({
                        'ID': order_id,
                        'city' : city,
                        'month' : m,
                        'day': d,
                        'hour': order_hour,
                        'minute': order_minute,
                        'prep_time': np.random.choice([1,5,10,15]),  # random prep time between 1 and 15 minutes
                        'customer': i,
                        'status': 'open'
                    }, index=[0])
                    order_id += 1
                    orders = pd.concat([orders, order], ignore_index=True)
                
        day_of_year += 1


orders
# Out:
#         ID       city month day hour minute prep_time customer status
# 0        0  Cambridge     1   1   13     30         1        2   open
# 1        1  Cambridge     1   1   16     55        10       18   open
# 2        2  Cambridge     1   1   20     40        15       23   open
# 3        3  Cambridge     1   1   19     25        10       25   open
# 4        4  Cambridge     1   1   17     25        15       27   open
# ...    ...        ...   ...  ..  ...    ...       ...      ...    ...
# 6358  6358  Cambridge    12  31   12     15        10       82   open
# 6359  6359  Cambridge    12  31   13     15        10       84   open
# 6360  6360  Cambridge    12  31   11     25        10       86   open
# 6361  6361  Cambridge    12  31   16     15         5       89   open
# 6362  6362  Cambridge    12  31   20     15         1       99   open
#
# [6363 rows x 9 columns]

# %%
# create a pack of robots
pack = []
pack.append(DeliveryRobot(name="Balto"))
pack.append(DeliveryRobot(name="Togo"))
pack.append(DeliveryRobot(name="Blackie"))
pack.append(DeliveryRobot(name="Fox"))

# display the pack
for robot in pack:
    print(robot)
# Out:
# Balto - SoC: 1.0, Status: IDLE
# Togo - SoC: 1.0, Status: IDLE
# Blackie - SoC: 1.0, Status: IDLE
# Fox - SoC: 1.0, Status: IDLE

# %%
def calculate_distance(customer_id):
    """
    Calculate the Euclidean distance between two locations.
    """
    x1, y1 = locations.iloc[0]['x'], locations.iloc[0]['y']
    x2, y2 = locations.iloc[customer_id]['x'], locations.iloc[customer_id]['y']

    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

def calculate_slopes(customer_id, distance):
    """
    Calculate the slope between store and order location.
    """

    if distance == 0:
        return 0.0, 0.0

    # Calculate the slope percentages for both directions
    e0 = locations.iloc[0]['elevation']
    e1 = locations.iloc[customer_id]['elevation']
    print(f'store elevation {e0}, customer elevation {e1}')
    return ((e1 - e0) / distance) * 100.0, ((e0 - e1) / distance) * 100.0,

def terrain_energy_factors(slope_out, slope_back):
    """
    Calculate the energy factor based on slope percentage.
    """
    if slope_out > 0:
        terrain_factor_out = 1.0 + 0.03 * slope_out  # increases with uphill
    else:
        terrain_factor_out = max(0.85, 1.0 + 0.02 * slope_out)  # energy saving, capped

    if slope_back > 0:
        terrain_factor_back = 1.0 + 0.03 * slope_back  # increases with uphill
    else:
        terrain_factor_back = max(0.85, 1.0 + 0.02 * slope_back)  # energy saving, capped

    return terrain_factor_out, terrain_factor_back

def calculate_weather_factor(weather_info):
    """
    Guesstimate the weather based impact on the trip - input is a list of weather dataframes
    """
    avg_temp = np.mean(weather_info['DryBulbTemperature_C'])
    avg_rain = np.mean(weather_info['synthetic_rain_mm'])

    # Base weather factor
    weather_factor = 1.0

    # Adjust for temperature - cold weather slows us down
    if avg_temp < 0:
        weather_factor *= 0.95
    elif avg_temp < 10:
        weather_factor *= 0.99

    # Rain effects — ignore anything under 2.5mm
    if avg_rain > 7.5:
        weather_factor *= 0.9
    elif avg_rain > 5.0:
        weather_factor *= 0.95
    elif avg_rain > 2.5:
        weather_factor *= 0.98
    # <2.5 → no adjustment
    
    return weather_factor

def speed_adjustment(slope_percent, base_speed_mps=1.2, weather_factor=1.0):
    """
    Adjusts speed based on slope and weather factor.
    Uphill slows you down, downhill helps a little.  Rain slows you down.
    """
    
    # Convert slope percentage to degrees
    slope_degrees = math.atan(slope_percent / 100) * (180 / math.pi)
    adjusted_speed = base_speed_mps

    # Adjust speed based on slope
    if slope_degrees > 0:
        adjusted_speed = base_speed_mps * (1 - slope_degrees / 45)  # Slower uphill
    else:
        adjusted_speed = base_speed_mps #* (1 + abs(slope_degrees) / 90)  # Faster downhill
    adjusted_speed = max(0.1, adjusted_speed * weather_factor)  # Adjust for weather

    return adjusted_speed

def speed_adjustments(slope_out_percent, slope_back_percent, base_speed_mps=1.2, weather_factor=1.0):
    """
    Adjusts speed based on slope and weather factor.
    Uphill slows you down, downhill helps a little.  Rain slows you down.
    """
    
    # Convert slope percentage to degrees
    slope_out_degrees = math.atan(slope_out_percent / 100) * (180 / math.pi)
    slope_back_degrees = math.atan(slope_back_percent / 100) * (180 / math.pi)
    adjusted_speed_out = base_speed_mps
    adjusted_speed_back = base_speed_mps
    # Adjust speed based on slope
    if slope_out_degrees > 0:
        adjusted_speed_out = base_speed_mps * (1 - slope_out_degrees / 45)  # Slower uphill
    else:
        adjusted_speed_out = base_speed_mps #* (1 + abs(slope_out_degrees) / 90)  # Faster downhill
    adjusted_speed_out = max(0.1, adjusted_speed_out * weather_factor)  # Adjust for weather

    if slope_back_degrees > 0:
        adjusted_speed_back = base_speed_mps * (1 - slope_back_degrees / 45)
    else:
        adjusted_speed_back = base_speed_mps #* (1 + abs(slope_back_degrees) / 90)
    adjusted_speed_back = max(0.1, adjusted_speed_back * weather_factor)

    return adjusted_speed_out, adjusted_speed_back

# Example usage
weather_info = weather[(weather['Month'] == 1) & (weather['Day'] == 1) & (weather['Hour'] == 12)]
weather_info = pd.concat([weather_info, weather[(weather['Month'] == 1) & (weather['Day'] == 1) & (weather['Hour'] == 13)]])
w_factor = calculate_weather_factor(weather_info)
print(f"Weather factor: {w_factor:.2f}")

# Example usage
customer = 38
dist = calculate_distance(customer)
slope_out, slope_back = calculate_slopes(customer, dist)
energy_factor_out, energy_factor_back = terrain_energy_factors(slope_out, slope_back)
speed_out, speed_back = speed_adjustments(slope_out, slope_back, w_factor)
print(f"Distance to customer {customer}: {dist:.2f} m over a slope of {slope_out:.2f} %, resulting in a slope energy factor of {energy_factor_out:.2f} out and {energy_factor_back:.2f} back")
print(f"Speed adjustment for slopes: {speed_out:.2f} m/s out and {speed_back:.2f} m/s back")


def estimated_time_to_customer(customer_id, weather_info):
    """
    Estimate time to customer based on distance, slope, and weather.
    """
    # Calculate distance and slopes
    distance = calculate_distance(customer_id)
    slope_out, _ = calculate_slopes(customer_id, distance)

    # Calculate weather factor
    weather_factor = calculate_weather_factor(weather_info)

    # Adjust speed
    speed_out, _ = speed_adjustments(slope_out, slope_back, weather_factor=weather_factor)

    # Calculate time to customer
    time_to_customer = (distance / speed_out) / 60

    return time_to_customer

print(f"Estimated time to customer {customer}: {estimated_time_to_customer(customer, weather_info):.2f} minutes")


def estimated_energy_consumption(customer_id, weather_info):
    """
    Estimate energy consumption for a trip to a customer.
    """
    # Calculate distance and slopes
    distance = calculate_distance(customer_id)
    distance_km = distance / 1000
    slope_out, slope_back = calculate_slopes(customer_id, distance)

    # Calculate weather factor
    weather_factor = calculate_weather_factor(weather_info)

    energy_factor_out, energy_factor_back = terrain_energy_factors(slope_out, slope_back)

    # Calculate energy consumption
    estimated_energy_required = (distance_km * weather_factor * energy_factor_out) + (distance_km * weather_factor * energy_factor_back)  

    return estimated_energy_required

print(f"Estimated energy consumption for customer {customer}: {estimated_energy_consumption(customer, weather_info):.2f} Wh")

def calculate_energy_consumption(distance, slope, weather_info):
    """
    Calculate energy consumption for a trip to a customer.
    """
    # Calculate distance and slopes
    distance_km = distance / 1000

    # Calculate weather factor
    weather_factor = calculate_weather_factor(weather_info)

    energy_factor, _ = terrain_energy_factors(slope, slope)
    # Calculate energy consumption
    estimated_energy_required = (distance_km * weather_factor * energy_factor)  

    return estimated_energy_required

print(calculate_energy_consumption(900, 3.4, weather))

def calculate_time_offset(h, m, offset):
    """
    given a time in hours and minutes, and an offset in minutes, what is the resulting time?
    """
    if offset > 0:
        # greater than an hour
        if m+offset >= 60:
            temp = h*60 + m + offset
            new_h = (temp // 60)
            new_m = (temp % 60)
        else:
            new_h = h
            new_m = m + offset
    else:
        print("Negative offset not supported")
        return h, m
    
    return new_h, new_m


print(calculate_time_offset(9, 13, 134))
# Out:
# Weather factor: 0.99
# store elevation 9.77, customer elevation 19.98
# Distance to customer 38: 1060.66 m over a slope of 0.96 %, resulting in a slope energy factor of 1.03 out and 0.98 back
# Speed adjustment for slopes: 0.98 m/s out and 0.99 m/s back
# store elevation 9.77, customer elevation 19.98
# Estimated time to customer 38: 15.06 minutes
# store elevation 9.77, customer elevation 19.98
# Estimated energy consumption for customer 38: 2.11 Wh
# 0.9818820000000001
# (11, 27)

# %%
# day loop
global current_hour, current_minute, month, day

# set the initial time
month = 1
day = 1

current_hour = 0
current_minute = 0

# these are the accepted taskings for the robots
taskings = []

# is called in a loop - for m in range(0, 1440):
def dispatch_logic(month, day, current_hour, current_minute):

    print(f"Dispatch logic at {current_hour}:{current_minute:02d} on {day}/{month}")

    # check the weather data for the last hour, the current hour and the next hour
    weather_info = weather[(weather['Month'] == month) & (weather['Day'] == day) & (weather['Hour'] == current_hour-1)]
    weather_info = pd.concat([weather_info, weather[(weather['Month'] == month) & (weather['Day'] == day) & (weather['Hour'] == current_hour)]])
    weather_info = pd.concat([weather_info, weather[(weather['Month'] == month) & (weather['Day'] == day) & (weather['Hour'] == current_hour+1)]])
    weather_factor = calculate_weather_factor(weather_info)

    # check for new orders
    new_orders = orders[(orders['month'] == month) & (orders['day'] == day) & (orders['hour'] == current_hour) & (orders['minute'] == current_minute)]

    if len(new_orders) > 0:
        
        print(f"New orders at {current_hour}:{current_minute:02d} - {len(new_orders)} new orders")
        for i, order in new_orders.iterrows():

            customer_id = order['customer']
            prep_time = order['prep_time']
            # distance
            dist_to_customer = calculate_distance(customer_id)
            slope_out, slope_back = calculate_slopes(customer_id, dist_to_customer)
            speed_out, speed_back = speed_adjustments(slope_out, slope_back, weather_factor=weather_factor)

            # time to customer - can we get there in time?
            expected_journey_time_to_customer = (dist_to_customer / speed_out) / 60  # in minutes
            if expected_journey_time_to_customer > 60:
                print(f"Order {order['ID']} for customer {customer_id} at location ({locations.loc[customer_id, 'x']}, {locations.loc[customer_id, 'y']}) - expected journey time: {expected_journey_time_to_customer:.2f} minutes - cannot accept order")
                order['status'] = 'rejected - cannot meet time'
            else:

                # expected arrival time at customer
                expected_arrival_time_at_customer = current_hour * 60 + current_minute + expected_journey_time_to_customer

                # energy expenditure for there and back
                expected_energy_for_order = estimated_energy_consumption(customer_id, weather_info)

                # are there untasked robot(s) with sufficient SoC?
                available_robots = [robot for robot in pack if robot.status == 'IDLE' and robot.battery.get_current_kwh() > expected_energy_for_order]
        
                # is a robot returning in time with sufficient time and expected battery charge to meet order?
                for robot in pack:
                    if robot.status == 'ON_TASK_RETURNING':
                        # check if the robot can return to base and then go to the customer
                        returning_task = robot.get_task_history()[-1]
                        

                        dist_to_base = calculate_distance(locations.loc[0, ['x', 'y']], robot.get_current_location())
                        _, slope_back = calculate_slopes(returning_task.get_order_id(), dist_to_base)
                        # energy expenditure for home and then there and back
                        expected_energy_for_return = calculate_energy_consumption(dist_to_base, slope_back, weather_factor)
                        expected_energy_for_total = expected_energy_for_order + expected_energy_for_return
                        
                        # time required for home and immediate load (1 min) and then there 
                        expected_time_for_return = (dist_to_base / speed_back) / 60
                        expected_extended_task_time = expected_time_for_return + 1 + expected_journey_time_to_customer
                        # this expected time is WRONG
                        expected_arrival_time_at_customer = current_hour * 60 + current_minute + expected_extended_task_time

                        if expected_extended_task_time < 60 and robot.battery.get_current_charge() > expected_energy_for_total:
                            available_robots.append(robot)

                # is a robot being charged such that it could reach sufficient SoC and meet window
                # for robot in pack:
                #     if robot.status == 'CHARGING':
                # TO DO        
                    

                if len(available_robots) == 0:
                    print(f"Order {order['ID']} for customer {customer_id} at location ({locations.loc[customer_id, 'x']}, {locations.loc[customer_id, 'y']}) - expected journey time: {expected_journey_time_to_customer:.2f} minutes - no robots available")
                    order['status'] = 'rejected - no robots available'
                else:
                    print(f"Order {order['ID']} for customer {customer_id} at location ({locations.loc[customer_id, 'x']}, {locations.loc[customer_id, 'y']}) - expected journey time: {expected_journey_time_to_customer:.2f} minutes - {len(available_robots)} robots available")
                    order['status'] = 'accepted - robot assigned'

                    # randomly select a robot from the available robots
                    robot = np.random.choice(available_robots)
                    task_start_hour, task_start_minute = calculate_time_offset(current_hour, current_minute, prep_time)
                    task = Task(order['ID'], robot.name, task_start_hour, task_start_minute)
                    taskings.append(task)                 
                                
                    print(f"Order {order['ID']} for customer {order['customer']} at location ({locations.loc[order['customer'], 'x']}, {locations.loc[order['customer'], 'y']}) - distance: {dist_to_customer:.2f} - tasked to {robot.name} expected arrival time: {expected_arrival_time_at_customer:.2f} minutes")

# main loop
# for m in range(1, 13):
#     for d in range(1, 29):

for m in range(1,2):
    for d in range(1,2):

        # check if we have reached the end of the month
        if d == 28 and m == 2:
            break     # check if we have reached the end of the month
        if d == 28 and m == 2:
            break
        elif d == 30 and m in [4, 6, 9, 11]:
            break
        elif d == 31 and m in [1, 3, 5, 7, 8, 10, 12]:
            break

        # set the month and day
        month = m
        day = d

        print(f"Processing month: {month}, day: {day}")

        current_hour = 0
        current_minute = 0

        # loop through the hours and minutes of the day
        for min in range(0, 1440):
            print(f"Processing minute: {min}")
            
            if min % 60 == 0:
                current_hour += 1
                current_minute = 0
            else:
                current_minute += 1
            print(f"Current time: {current_hour}:{current_minute:02d} on {day}/{month}")

            # check weather data for the current hour
            weather_now = weather[(weather['Month'] == month) & (weather['Day'] == day) & (weather['Hour'] == current_hour)]
            if weather_now['synthetic_rain_mm'].values[0] > 10:
                print(f"Heavy rain at {current_hour}:{current_minute:02d} - too dangerous to operate")
            else: 
                # dispatch logic
                dispatch_logic(month, day, current_hour, current_minute)


            # # have we reached the end of the day?
            # if current_hour == 21 and current_minute == 0:
            #     print(f"End of day reached: {current_hour}:{current_minute:02d} on {day}/{month}")
            #     break
# Out:
# Processing month: 1, day: 1
# Processing minute: 0
# Current time: 1:00 on 1/1
# Dispatch logic at 1:00 on 1/1
# Processing minute: 1
# Current time: 1:01 on 1/1
# Dispatch logic at 1:01 on 1/1
# Processing minute: 2
# Current time: 1:02 on 1/1
# Dispatch logic at 1:02 on 1/1
# Processing minute: 3
# Current time: 1:03 on 1/1
# Dispatch logic at 1:03 on 1/1
# Processing minute: 4
# Current time: 1:04 on 1/1
# Dispatch logic at 1:04 on 1/1
# Processing minute: 5
# Current time: 1:05 on 1/1
# Dispatch logic at 1:05 on 1/1
# Processing minute: 6
# Current time: 1:06 on 1/1
# Dispatch logic at 1:06 on 1/1
# Processing minute: 7
# Current time: 1:07 on 1/1
# Dispatch logic at 1:07 on 1/1
# Processing minute: 8
# Current time: 1:08 on 1/1
# Dispatch logic at 1:08 on 1/1
# Processing minute: 9
# Current time: 1:09 on 1/1
# Dispatch logic at 1:09 on 1/1
# Processing minute: 10
# Current time: 1:10 on 1/1
# Dispatch logic at 1:10 on 1/1
# Processing minute: 11
# Current time: 1:11 on 1/1
# Dispatch logic at 1:11 on 1/1
# Processing minute: 12
# Current time: 1:12 on 1/1
# Dispatch logic at 1:12 on 1/1
# Processing minute: 13
# Current time: 1:13 on 1/1
# Dispatch logic at 1:13 on 1/1
# Processing minute: 14
# Current time: 1:14 on 1/1
# Dispatch logic at 1:14 on 1/1
# Processing minute: 15
# Current time: 1:15 on 1/1
# Dispatch logic at 1:15 on 1/1
# Processing minute: 16
# Current time: 1:16 on 1/1
# Dispatch logic at 1:16 on 1/1
# Processing minute: 17
# Current time: 1:17 on 1/1
# Dispatch logic at 1:17 on 1/1
# Processing minute: 18
# Current time: 1:18 on 1/1
# Dispatch logic at 1:18 on 1/1
# Processing minute: 19
# Current time: 1:19 on 1/1
# Dispatch logic at 1:19 on 1/1
# Processing minute: 20
# Current time: 1:20 on 1/1
# Dispatch logic at 1:20 on 1/1
# Processing minute: 21
# Current time: 1:21 on 1/1
# Dispatch logic at 1:21 on 1/1
# Processing minute: 22
# Current time: 1:22 on 1/1
# Dispatch logic at 1:22 on 1/1
# Processing minute: 23
# Current time: 1:23 on 1/1
# Dispatch logic at 1:23 on 1/1
# Processing minute: 24
# Current time: 1:24 on 1/1
# Dispatch logic at 1:24 on 1/1
# Processing minute: 25
# Current time: 1:25 on 1/1
# Dispatch logic at 1:25 on 1/1
# Processing minute: 26
# Current time: 1:26 on 1/1
# Dispatch logic at 1:26 on 1/1
# Processing minute: 27
# Current time: 1:27 on 1/1
# Dispatch logic at 1:27 on 1/1
# Processing minute: 28
# Current time: 1:28 on 1/1
# Dispatch logic at 1:28 on 1/1
# Processing minute: 29
# Current time: 1:29 on 1/1
# Dispatch logic at 1:29 on 1/1
# Processing minute: 30
# Current time: 1:30 on 1/1
# Dispatch logic at 1:30 on 1/1
# Processing minute: 31
# Current time: 1:31 on 1/1
# Dispatch logic at 1:31 on 1/1
# Processing minute: 32
# Current time: 1:32 on 1/1
# Dispatch logic at 1:32 on 1/1
# Processing minute: 33
# Current time: 1:33 on 1/1
# Dispatch logic at 1:33 on 1/1
# Processing minute: 34
# Current time: 1:34 on 1/1
# Dispatch logic at 1:34 on 1/1
# Processing minute: 35
# Current time: 1:35 on 1/1
# Dispatch logic at 1:35 on 1/1
# Processing minute: 36
# Current time: 1:36 on 1/1
# Dispatch logic at 1:36 on 1/1
# Processing minute: 37
# Current time: 1:37 on 1/1
# Dispatch logic at 1:37 on 1/1
# Processing minute: 38
# Current time: 1:38 on 1/1
# Dispatch logic at 1:38 on 1/1
# Processing minute: 39
# Current time: 1:39 on 1/1
# Dispatch logic at 1:39 on 1/1
# Processing minute: 40
# Current time: 1:40 on 1/1
# Dispatch logic at 1:40 on 1/1
# Processing minute: 41
# Current time: 1:41 on 1/1
# Dispatch logic at 1:41 on 1/1
# Processing minute: 42
# Current time: 1:42 on 1/1
# Dispatch logic at 1:42 on 1/1
# Processing minute: 43
# Current time: 1:43 on 1/1
# Dispatch logic at 1:43 on 1/1
# Processing minute: 44
# Current time: 1:44 on 1/1
# Dispatch logic at 1:44 on 1/1
# Processing minute: 45
# Current time: 1:45 on 1/1
# Dispatch logic at 1:45 on 1/1
# Processing minute: 46
# Current time: 1:46 on 1/1
# Dispatch logic at 1:46 on 1/1
# Processing minute: 47
# Current time: 1:47 on 1/1
# Dispatch logic at 1:47 on 1/1
# Processing minute: 48
# Current time: 1:48 on 1/1
# Dispatch logic at 1:48 on 1/1
# Processing minute: 49
# Current time: 1:49 on 1/1
# Dispatch logic at 1:49 on 1/1
# Processing minute: 50
# Current time: 1:50 on 1/1
# Dispatch logic at 1:50 on 1/1
# Processing minute: 51
# Current time: 1:51 on 1/1
# Dispatch logic at 1:51 on 1/1
# Processing minute: 52
# Current time: 1:52 on 1/1
# Dispatch logic at 1:52 on 1/1
# Processing minute: 53
# Current time: 1:53 on 1/1
# Dispatch logic at 1:53 on 1/1
# Processing minute: 54
# Current time: 1:54 on 1/1
# Dispatch logic at 1:54 on 1/1
# Processing minute: 55
# Current time: 1:55 on 1/1
# Dispatch logic at 1:55 on 1/1
# Processing minute: 56
# Current time: 1:56 on 1/1
# Dispatch logic at 1:56 on 1/1
# Processing minute: 57
# Current time: 1:57 on 1/1
# Dispatch logic at 1:57 on 1/1
# Processing minute: 58
# Current time: 1:58 on 1/1
# Dispatch logic at 1:58 on 1/1
# Processing minute: 59
# Current time: 1:59 on 1/1
# Dispatch logic at 1:59 on 1/1
# Processing minute: 60
# Current time: 2:00 on 1/1
# Dispatch logic at 2:00 on 1/1
# Processing minute: 61
# Current time: 2:01 on 1/1
# Dispatch logic at 2:01 on 1/1
# Processing minute: 62
# Current time: 2:02 on 1/1
# Dispatch logic at 2:02 on 1/1
# Processing minute: 63
# Current time: 2:03 on 1/1
# Dispatch logic at 2:03 on 1/1
# Processing minute: 64
# Current time: 2:04 on 1/1
# Dispatch logic at 2:04 on 1/1
# Processing minute: 65
# Current time: 2:05 on 1/1
# Dispatch logic at 2:05 on 1/1
# Processing minute: 66
# Current time: 2:06 on 1/1
# Dispatch logic at 2:06 on 1/1
# Processing minute: 67
# Current time: 2:07 on 1/1
# Dispatch logic at 2:07 on 1/1
# Processing minute: 68
# Current time: 2:08 on 1/1
# Dispatch logic at 2:08 on 1/1
# Processing minute: 69
# Current time: 2:09 on 1/1
# Dispatch logic at 2:09 on 1/1
# Processing minute: 70
# Current time: 2:10 on 1/1
# Dispatch logic at 2:10 on 1/1
# Processing minute: 71
# Current time: 2:11 on 1/1
# Dispatch logic at 2:11 on 1/1
# Processing minute: 72
# Current time: 2:12 on 1/1
# Dispatch logic at 2:12 on 1/1
# Processing minute: 73
# Current time: 2:13 on 1/1
# Dispatch logic at 2:13 on 1/1
# Processing minute: 74
# Current time: 2:14 on 1/1
# Dispatch logic at 2:14 on 1/1
# Processing minute: 75
# Current time: 2:15 on 1/1
# Dispatch logic at 2:15 on 1/1
# Processing minute: 76
# Current time: 2:16 on 1/1
# Dispatch logic at 2:16 on 1/1
# Processing minute: 77
# Current time: 2:17 on 1/1
# Dispatch logic at 2:17 on 1/1
# Processing minute: 78
# Current time: 2:18 on 1/1
# Dispatch logic at 2:18 on 1/1
# Processing minute: 79
# Current time: 2:19 on 1/1
# Dispatch logic at 2:19 on 1/1
# Processing minute: 80
# Current time: 2:20 on 1/1
# Dispatch logic at 2:20 on 1/1
# Processing minute: 81
# Current time: 2:21 on 1/1
# Dispatch logic at 2:21 on 1/1
# Processing minute: 82
# Current time: 2:22 on 1/1
# Dispatch logic at 2:22 on 1/1
# Processing minute: 83
# Current time: 2:23 on 1/1
# Dispatch logic at 2:23 on 1/1
# Processing minute: 84
# Current time: 2:24 on 1/1
# Dispatch logic at 2:24 on 1/1
# Processing minute: 85
# Current time: 2:25 on 1/1
# Dispatch logic at 2:25 on 1/1
# Processing minute: 86
# Current time: 2:26 on 1/1
# Dispatch logic at 2:26 on 1/1
# Processing minute: 87
# Current time: 2:27 on 1/1
# Dispatch logic at 2:27 on 1/1
# Processing minute: 88
# Current time: 2:28 on 1/1
# Dispatch logic at 2:28 on 1/1
# Processing minute: 89
# Current time: 2:29 on 1/1
# Dispatch logic at 2:29 on 1/1
# Processing minute: 90
# Current time: 2:30 on 1/1
# Dispatch logic at 2:30 on 1/1
# Processing minute: 91
# Current time: 2:31 on 1/1
# Dispatch logic at 2:31 on 1/1
# Processing minute: 92
# Current time: 2:32 on 1/1
# Dispatch logic at 2:32 on 1/1
# Processing minute: 93
# Current time: 2:33 on 1/1
# Dispatch logic at 2:33 on 1/1
# Processing minute: 94
# Current time: 2:34 on 1/1
# Dispatch logic at 2:34 on 1/1
# Processing minute: 95
# Current time: 2:35 on 1/1
# Dispatch logic at 2:35 on 1/1
# Processing minute: 96
# Current time: 2:36 on 1/1
# Dispatch logic at 2:36 on 1/1
# Processing minute: 97
# Current time: 2:37 on 1/1
# Dispatch logic at 2:37 on 1/1
# Processing minute: 98
# Current time: 2:38 on 1/1
# Dispatch logic at 2:38 on 1/1
# Processing minute: 99
# Current time: 2:39 on 1/1
# Dispatch logic at 2:39 on 1/1
# Processing minute: 100
# Current time: 2:40 on 1/1
# Dispatch logic at 2:40 on 1/1
# Processing minute: 101
# Current time: 2:41 on 1/1
# Dispatch logic at 2:41 on 1/1
# Processing minute: 102
# Current time: 2:42 on 1/1
# Dispatch logic at 2:42 on 1/1
# Processing minute: 103
# Current time: 2:43 on 1/1
# Dispatch logic at 2:43 on 1/1
# Processing minute: 104
# Current time: 2:44 on 1/1
# Dispatch logic at 2:44 on 1/1
# Processing minute: 105
# Current time: 2:45 on 1/1
# Dispatch logic at 2:45 on 1/1
# Processing minute: 106
# Current time: 2:46 on 1/1
# Dispatch logic at 2:46 on 1/1
# Processing minute: 107
# Current time: 2:47 on 1/1
# Dispatch logic at 2:47 on 1/1
# Processing minute: 108
# Current time: 2:48 on 1/1
# Dispatch logic at 2:48 on 1/1
# Processing minute: 109
# Current time: 2:49 on 1/1
# Dispatch logic at 2:49 on 1/1
# Processing minute: 110
# Current time: 2:50 on 1/1
# Dispatch logic at 2:50 on 1/1
# Processing minute: 111
# Current time: 2:51 on 1/1
# Dispatch logic at 2:51 on 1/1
# Processing minute: 112
# Current time: 2:52 on 1/1
# Dispatch logic at 2:52 on 1/1
# Processing minute: 113
# Current time: 2:53 on 1/1
# Dispatch logic at 2:53 on 1/1
# Processing minute: 114
# Current time: 2:54 on 1/1
# Dispatch logic at 2:54 on 1/1
# Processing minute: 115
# Current time: 2:55 on 1/1
# Dispatch logic at 2:55 on 1/1
# Processing minute: 116
# Current time: 2:56 on 1/1
# Dispatch logic at 2:56 on 1/1
# Processing minute: 117
# Current time: 2:57 on 1/1
# Dispatch logic at 2:57 on 1/1
# Processing minute: 118
# Current time: 2:58 on 1/1
# Dispatch logic at 2:58 on 1/1
# Processing minute: 119
# Current time: 2:59 on 1/1
# Dispatch logic at 2:59 on 1/1
# Processing minute: 120
# Current time: 3:00 on 1/1
# Dispatch logic at 3:00 on 1/1
# Processing minute: 121
# Current time: 3:01 on 1/1
# Dispatch logic at 3:01 on 1/1
# Processing minute: 122
# Current time: 3:02 on 1/1
# Dispatch logic at 3:02 on 1/1
# Processing minute: 123
# Current time: 3:03 on 1/1
# Dispatch logic at 3:03 on 1/1
# Processing minute: 124
# Current time: 3:04 on 1/1
# Dispatch logic at 3:04 on 1/1
# Processing minute: 125
# Current time: 3:05 on 1/1
# Dispatch logic at 3:05 on 1/1
# Processing minute: 126
# Current time: 3:06 on 1/1
# Dispatch logic at 3:06 on 1/1
# Processing minute: 127
# Current time: 3:07 on 1/1
# Dispatch logic at 3:07 on 1/1
# Processing minute: 128
# Current time: 3:08 on 1/1
# Dispatch logic at 3:08 on 1/1
# Processing minute: 129
# Current time: 3:09 on 1/1
# Dispatch logic at 3:09 on 1/1
# Processing minute: 130
# Current time: 3:10 on 1/1
# Dispatch logic at 3:10 on 1/1
# Processing minute: 131
# Current time: 3:11 on 1/1
# Dispatch logic at 3:11 on 1/1
# Processing minute: 132
# Current time: 3:12 on 1/1
# Dispatch logic at 3:12 on 1/1
# Processing minute: 133
# Current time: 3:13 on 1/1
# Dispatch logic at 3:13 on 1/1
# Processing minute: 134
# Current time: 3:14 on 1/1
# Dispatch logic at 3:14 on 1/1
# Processing minute: 135
# Current time: 3:15 on 1/1
# Dispatch logic at 3:15 on 1/1
# Processing minute: 136
# Current time: 3:16 on 1/1
# Dispatch logic at 3:16 on 1/1
# Processing minute: 137
# Current time: 3:17 on 1/1
# Dispatch logic at 3:17 on 1/1
# Processing minute: 138
# Current time: 3:18 on 1/1
# Dispatch logic at 3:18 on 1/1
# Processing minute: 139
# Current time: 3:19 on 1/1
# Dispatch logic at 3:19 on 1/1
# Processing minute: 140
# Current time: 3:20 on 1/1
# Dispatch logic at 3:20 on 1/1
# Processing minute: 141
# Current time: 3:21 on 1/1
# Dispatch logic at 3:21 on 1/1
# Processing minute: 142
# Current time: 3:22 on 1/1
# Dispatch logic at 3:22 on 1/1
# Processing minute: 143
# Current time: 3:23 on 1/1
# Dispatch logic at 3:23 on 1/1
# Processing minute: 144
# Current time: 3:24 on 1/1
# Dispatch logic at 3:24 on 1/1
# Processing minute: 145
# Current time: 3:25 on 1/1
# Dispatch logic at 3:25 on 1/1
# Processing minute: 146
# Current time: 3:26 on 1/1
# Dispatch logic at 3:26 on 1/1
# Processing minute: 147
# Current time: 3:27 on 1/1
# Dispatch logic at 3:27 on 1/1
# Processing minute: 148
# Current time: 3:28 on 1/1
# Dispatch logic at 3:28 on 1/1
# Processing minute: 149
# Current time: 3:29 on 1/1
# Dispatch logic at 3:29 on 1/1
# Processing minute: 150
# Current time: 3:30 on 1/1
# Dispatch logic at 3:30 on 1/1
# Processing minute: 151
# Current time: 3:31 on 1/1
# Dispatch logic at 3:31 on 1/1
# Processing minute: 152
# Current time: 3:32 on 1/1
# Dispatch logic at 3:32 on 1/1
# Processing minute: 153
# Current time: 3:33 on 1/1
# Dispatch logic at 3:33 on 1/1
# Processing minute: 154
# Current time: 3:34 on 1/1
# Dispatch logic at 3:34 on 1/1
# Processing minute: 155
# Current time: 3:35 on 1/1
# Dispatch logic at 3:35 on 1/1
# Processing minute: 156
# Current time: 3:36 on 1/1
# Dispatch logic at 3:36 on 1/1
# Processing minute: 157
# Current time: 3:37 on 1/1
# Dispatch logic at 3:37 on 1/1
# Processing minute: 158
# Current time: 3:38 on 1/1
# Dispatch logic at 3:38 on 1/1
# Processing minute: 159
# Current time: 3:39 on 1/1
# Dispatch logic at 3:39 on 1/1
# Processing minute: 160
# Current time: 3:40 on 1/1
# Dispatch logic at 3:40 on 1/1
# Processing minute: 161
# Current time: 3:41 on 1/1
# Dispatch logic at 3:41 on 1/1
# Processing minute: 162
# Current time: 3:42 on 1/1
# Dispatch logic at 3:42 on 1/1
# Processing minute: 163
# Current time: 3:43 on 1/1
# Dispatch logic at 3:43 on 1/1
# Processing minute: 164
# Current time: 3:44 on 1/1
# Dispatch logic at 3:44 on 1/1
# Processing minute: 165
# Current time: 3:45 on 1/1
# Dispatch logic at 3:45 on 1/1
# Processing minute: 166
# Current time: 3:46 on 1/1
# Dispatch logic at 3:46 on 1/1
# Processing minute: 167
# Current time: 3:47 on 1/1
# Dispatch logic at 3:47 on 1/1
# Processing minute: 168
# Current time: 3:48 on 1/1
# Dispatch logic at 3:48 on 1/1
# Processing minute: 169
# Current time: 3:49 on 1/1
# Dispatch logic at 3:49 on 1/1
# Processing minute: 170
# Current time: 3:50 on 1/1
# Dispatch logic at 3:50 on 1/1
# Processing minute: 171
# Current time: 3:51 on 1/1
# Dispatch logic at 3:51 on 1/1
# Processing minute: 172
# Current time: 3:52 on 1/1
# Dispatch logic at 3:52 on 1/1
# Processing minute: 173
# Current time: 3:53 on 1/1
# Dispatch logic at 3:53 on 1/1
# Processing minute: 174
# Current time: 3:54 on 1/1
# Dispatch logic at 3:54 on 1/1
# Processing minute: 175
# Current time: 3:55 on 1/1
# Dispatch logic at 3:55 on 1/1
# Processing minute: 176
# Current time: 3:56 on 1/1
# Dispatch logic at 3:56 on 1/1
# Processing minute: 177
# Current time: 3:57 on 1/1
# Dispatch logic at 3:57 on 1/1
# Processing minute: 178
# Current time: 3:58 on 1/1
# Dispatch logic at 3:58 on 1/1
# Processing minute: 179
# Current time: 3:59 on 1/1
# Dispatch logic at 3:59 on 1/1
# Processing minute: 180
# Current time: 4:00 on 1/1
# Dispatch logic at 4:00 on 1/1
# Processing minute: 181
# Current time: 4:01 on 1/1
# Dispatch logic at 4:01 on 1/1
# Processing minute: 182
# Current time: 4:02 on 1/1
# Dispatch logic at 4:02 on 1/1
# Processing minute: 183
# Current time: 4:03 on 1/1
# Dispatch logic at 4:03 on 1/1
# Processing minute: 184
# Current time: 4:04 on 1/1
# Dispatch logic at 4:04 on 1/1
# Processing minute: 185
# Current time: 4:05 on 1/1
# Dispatch logic at 4:05 on 1/1
# Processing minute: 186
# Current time: 4:06 on 1/1
# Dispatch logic at 4:06 on 1/1
# Processing minute: 187
# Current time: 4:07 on 1/1
# Dispatch logic at 4:07 on 1/1
# Processing minute: 188
# Current time: 4:08 on 1/1
# Dispatch logic at 4:08 on 1/1
# Processing minute: 189
# Current time: 4:09 on 1/1
# Dispatch logic at 4:09 on 1/1
# Processing minute: 190
# Current time: 4:10 on 1/1
# Dispatch logic at 4:10 on 1/1
# Processing minute: 191
# Current time: 4:11 on 1/1
# Dispatch logic at 4:11 on 1/1
# Processing minute: 192
# Current time: 4:12 on 1/1
# Dispatch logic at 4:12 on 1/1
# Processing minute: 193
# Current time: 4:13 on 1/1
# Dispatch logic at 4:13 on 1/1
# Processing minute: 194
# Current time: 4:14 on 1/1
# Dispatch logic at 4:14 on 1/1
# Processing minute: 195
# Current time: 4:15 on 1/1
# Dispatch logic at 4:15 on 1/1
# Processing minute: 196
# Current time: 4:16 on 1/1
# Dispatch logic at 4:16 on 1/1
# Processing minute: 197
# Current time: 4:17 on 1/1
# Dispatch logic at 4:17 on 1/1
# Processing minute: 198
# Current time: 4:18 on 1/1
# Dispatch logic at 4:18 on 1/1
# Processing minute: 199
# Current time: 4:19 on 1/1
# Dispatch logic at 4:19 on 1/1
# Processing minute: 200
# Current time: 4:20 on 1/1
# Dispatch logic at 4:20 on 1/1
# Processing minute: 201
# Current time: 4:21 on 1/1
# Dispatch logic at 4:21 on 1/1
# Processing minute: 202
# Current time: 4:22 on 1/1
# Dispatch logic at 4:22 on 1/1
# Processing minute: 203
# Current time: 4:23 on 1/1
# Dispatch logic at 4:23 on 1/1
# Processing minute: 204
# Current time: 4:24 on 1/1
# Dispatch logic at 4:24 on 1/1
# Processing minute: 205
# Current time: 4:25 on 1/1
# Dispatch logic at 4:25 on 1/1
# Processing minute: 206
# Current time: 4:26 on 1/1
# Dispatch logic at 4:26 on 1/1
# Processing minute: 207
# Current time: 4:27 on 1/1
# Dispatch logic at 4:27 on 1/1
# Processing minute: 208
# Current time: 4:28 on 1/1
# Dispatch logic at 4:28 on 1/1
# Processing minute: 209
# Current time: 4:29 on 1/1
# Dispatch logic at 4:29 on 1/1
# Processing minute: 210
# Current time: 4:30 on 1/1
# Dispatch logic at 4:30 on 1/1
# Processing minute: 211
# Current time: 4:31 on 1/1
# Dispatch logic at 4:31 on 1/1
# Processing minute: 212
# Current time: 4:32 on 1/1
# Dispatch logic at 4:32 on 1/1
# Processing minute: 213
# Current time: 4:33 on 1/1
# Dispatch logic at 4:33 on 1/1
# Processing minute: 214
# Current time: 4:34 on 1/1
# Dispatch logic at 4:34 on 1/1
# Processing minute: 215
# Current time: 4:35 on 1/1
# Dispatch logic at 4:35 on 1/1
# Processing minute: 216
# Current time: 4:36 on 1/1
# Dispatch logic at 4:36 on 1/1
# Processing minute: 217
# Current time: 4:37 on 1/1
# Dispatch logic at 4:37 on 1/1
# Processing minute: 218
# Current time: 4:38 on 1/1
# Dispatch logic at 4:38 on 1/1
# Processing minute: 219
# Current time: 4:39 on 1/1
# Dispatch logic at 4:39 on 1/1
# Processing minute: 220
# Current time: 4:40 on 1/1
# Dispatch logic at 4:40 on 1/1
# Processing minute: 221
# Current time: 4:41 on 1/1
# Dispatch logic at 4:41 on 1/1
# Processing minute: 222
# Current time: 4:42 on 1/1
# Dispatch logic at 4:42 on 1/1
# Processing minute: 223
# Current time: 4:43 on 1/1
# Dispatch logic at 4:43 on 1/1
# Processing minute: 224
# Current time: 4:44 on 1/1
# Dispatch logic at 4:44 on 1/1
# Processing minute: 225
# Current time: 4:45 on 1/1
# Dispatch logic at 4:45 on 1/1
# Processing minute: 226
# Current time: 4:46 on 1/1
# Dispatch logic at 4:46 on 1/1
# Processing minute: 227
# Current time: 4:47 on 1/1
# Dispatch logic at 4:47 on 1/1
# Processing minute: 228
# Current time: 4:48 on 1/1
# Dispatch logic at 4:48 on 1/1
# Processing minute: 229
# Current time: 4:49 on 1/1
# Dispatch logic at 4:49 on 1/1
# Processing minute: 230
# Current time: 4:50 on 1/1
# Dispatch logic at 4:50 on 1/1
# Processing minute: 231
# Current time: 4:51 on 1/1
# Dispatch logic at 4:51 on 1/1
# Processing minute: 232
# Current time: 4:52 on 1/1
# Dispatch logic at 4:52 on 1/1
# Processing minute: 233
# Current time: 4:53 on 1/1
# Dispatch logic at 4:53 on 1/1
# Processing minute: 234
# Current time: 4:54 on 1/1
# Dispatch logic at 4:54 on 1/1
# Processing minute: 235
# Current time: 4:55 on 1/1
# Dispatch logic at 4:55 on 1/1
# Processing minute: 236
# Current time: 4:56 on 1/1
# Dispatch logic at 4:56 on 1/1
# Processing minute: 237
# Current time: 4:57 on 1/1
# Dispatch logic at 4:57 on 1/1
# Processing minute: 238
# Current time: 4:58 on 1/1
# Dispatch logic at 4:58 on 1/1
# Processing minute: 239
# Current time: 4:59 on 1/1
# Dispatch logic at 4:59 on 1/1
# Processing minute: 240
# Current time: 5:00 on 1/1
# Dispatch logic at 5:00 on 1/1
# Processing minute: 241
# Current time: 5:01 on 1/1
# Dispatch logic at 5:01 on 1/1
# Processing minute: 242
# Current time: 5:02 on 1/1
# Dispatch logic at 5:02 on 1/1
# Processing minute: 243
# Current time: 5:03 on 1/1
# Dispatch logic at 5:03 on 1/1
# Processing minute: 244
# Current time: 5:04 on 1/1
# Dispatch logic at 5:04 on 1/1
# Processing minute: 245
# Current time: 5:05 on 1/1
# Dispatch logic at 5:05 on 1/1
# Processing minute: 246
# Current time: 5:06 on 1/1
# Dispatch logic at 5:06 on 1/1
# Processing minute: 247
# Current time: 5:07 on 1/1
# Dispatch logic at 5:07 on 1/1
# Processing minute: 248
# Current time: 5:08 on 1/1
# Dispatch logic at 5:08 on 1/1
# Processing minute: 249
# Current time: 5:09 on 1/1
# Dispatch logic at 5:09 on 1/1
# Processing minute: 250
# Current time: 5:10 on 1/1
# Dispatch logic at 5:10 on 1/1
# Processing minute: 251
# Current time: 5:11 on 1/1
# Dispatch logic at 5:11 on 1/1
# Processing minute: 252
# Current time: 5:12 on 1/1
# Dispatch logic at 5:12 on 1/1
# Processing minute: 253
# Current time: 5:13 on 1/1
# Dispatch logic at 5:13 on 1/1
# Processing minute: 254
# Current time: 5:14 on 1/1
# Dispatch logic at 5:14 on 1/1
# Processing minute: 255
# Current time: 5:15 on 1/1
# Dispatch logic at 5:15 on 1/1
# Processing minute: 256
# Current time: 5:16 on 1/1
# Dispatch logic at 5:16 on 1/1
# Processing minute: 257
# Current time: 5:17 on 1/1
# Dispatch logic at 5:17 on 1/1
# Processing minute: 258
# Current time: 5:18 on 1/1
# Dispatch logic at 5:18 on 1/1
# Processing minute: 259
# Current time: 5:19 on 1/1
# Dispatch logic at 5:19 on 1/1
# Processing minute: 260
# Current time: 5:20 on 1/1
# Dispatch logic at 5:20 on 1/1
# Processing minute: 261
# Current time: 5:21 on 1/1
# Dispatch logic at 5:21 on 1/1
# Processing minute: 262
# Current time: 5:22 on 1/1
# Dispatch logic at 5:22 on 1/1
# Processing minute: 263
# Current time: 5:23 on 1/1
# Dispatch logic at 5:23 on 1/1
# Processing minute: 264
# Current time: 5:24 on 1/1
# Dispatch logic at 5:24 on 1/1
# Processing minute: 265
# Current time: 5:25 on 1/1
# Dispatch logic at 5:25 on 1/1
# Processing minute: 266
# Current time: 5:26 on 1/1
# Dispatch logic at 5:26 on 1/1
# Processing minute: 267
# Current time: 5:27 on 1/1
# Dispatch logic at 5:27 on 1/1
# Processing minute: 268
# Current time: 5:28 on 1/1
# Dispatch logic at 5:28 on 1/1
# Processing minute: 269
# Current time: 5:29 on 1/1
# Dispatch logic at 5:29 on 1/1
# Processing minute: 270
# Current time: 5:30 on 1/1
# Dispatch logic at 5:30 on 1/1
# Processing minute: 271
# Current time: 5:31 on 1/1
# Dispatch logic at 5:31 on 1/1
# Processing minute: 272
# Current time: 5:32 on 1/1
# Dispatch logic at 5:32 on 1/1
# Processing minute: 273
# Current time: 5:33 on 1/1
# Dispatch logic at 5:33 on 1/1
# Processing minute: 274
# Current time: 5:34 on 1/1
# Dispatch logic at 5:34 on 1/1
# Processing minute: 275
# Current time: 5:35 on 1/1
# Dispatch logic at 5:35 on 1/1
# Processing minute: 276
# Current time: 5:36 on 1/1
# Dispatch logic at 5:36 on 1/1
# Processing minute: 277
# Current time: 5:37 on 1/1
# Dispatch logic at 5:37 on 1/1
# Processing minute: 278
# Current time: 5:38 on 1/1
# Dispatch logic at 5:38 on 1/1
# Processing minute: 279
# Current time: 5:39 on 1/1
# Dispatch logic at 5:39 on 1/1
# Processing minute: 280
# Current time: 5:40 on 1/1
# Dispatch logic at 5:40 on 1/1
# Processing minute: 281
# Current time: 5:41 on 1/1
# Dispatch logic at 5:41 on 1/1
# Processing minute: 282
# Current time: 5:42 on 1/1
# Dispatch logic at 5:42 on 1/1
# Processing minute: 283
# Current time: 5:43 on 1/1
# Dispatch logic at 5:43 on 1/1
# Processing minute: 284
# Current time: 5:44 on 1/1
# Dispatch logic at 5:44 on 1/1
# Processing minute: 285
# Current time: 5:45 on 1/1
# Dispatch logic at 5:45 on 1/1
# Processing minute: 286
# Current time: 5:46 on 1/1
# Dispatch logic at 5:46 on 1/1
# Processing minute: 287
# Current time: 5:47 on 1/1
# Dispatch logic at 5:47 on 1/1
# Processing minute: 288
# Current time: 5:48 on 1/1
# Dispatch logic at 5:48 on 1/1
# Processing minute: 289
# Current time: 5:49 on 1/1
# Dispatch logic at 5:49 on 1/1
# Processing minute: 290
# Current time: 5:50 on 1/1
# Dispatch logic at 5:50 on 1/1
# Processing minute: 291
# Current time: 5:51 on 1/1
# Dispatch logic at 5:51 on 1/1
# Processing minute: 292
# Current time: 5:52 on 1/1
# Dispatch logic at 5:52 on 1/1
# Processing minute: 293
# Current time: 5:53 on 1/1
# Dispatch logic at 5:53 on 1/1
# Processing minute: 294
# Current time: 5:54 on 1/1
# Dispatch logic at 5:54 on 1/1
# Processing minute: 295
# Current time: 5:55 on 1/1
# Dispatch logic at 5:55 on 1/1
# Processing minute: 296
# Current time: 5:56 on 1/1
# Dispatch logic at 5:56 on 1/1
# Processing minute: 297
# Current time: 5:57 on 1/1
# Dispatch logic at 5:57 on 1/1
# Processing minute: 298
# Current time: 5:58 on 1/1
# Dispatch logic at 5:58 on 1/1
# Processing minute: 299
# Current time: 5:59 on 1/1
# Dispatch logic at 5:59 on 1/1
# Processing minute: 300
# Current time: 6:00 on 1/1
# Dispatch logic at 6:00 on 1/1
# Processing minute: 301
# Current time: 6:01 on 1/1
# Dispatch logic at 6:01 on 1/1
# Processing minute: 302
# Current time: 6:02 on 1/1
# Dispatch logic at 6:02 on 1/1
# Processing minute: 303
# Current time: 6:03 on 1/1
# Dispatch logic at 6:03 on 1/1
# Processing minute: 304
# Current time: 6:04 on 1/1
# Dispatch logic at 6:04 on 1/1
# Processing minute: 305
# Current time: 6:05 on 1/1
# Dispatch logic at 6:05 on 1/1
# Processing minute: 306
# Current time: 6:06 on 1/1
# Dispatch logic at 6:06 on 1/1
# Processing minute: 307
# Current time: 6:07 on 1/1
# Dispatch logic at 6:07 on 1/1
# Processing minute: 308
# Current time: 6:08 on 1/1
# Dispatch logic at 6:08 on 1/1
# Processing minute: 309
# Current time: 6:09 on 1/1
# Dispatch logic at 6:09 on 1/1
# Processing minute: 310
# Current time: 6:10 on 1/1
# Dispatch logic at 6:10 on 1/1
# Processing minute: 311
# Current time: 6:11 on 1/1
# Dispatch logic at 6:11 on 1/1
# Processing minute: 312
# Current time: 6:12 on 1/1
# Dispatch logic at 6:12 on 1/1
# Processing minute: 313
# Current time: 6:13 on 1/1
# Dispatch logic at 6:13 on 1/1
# Processing minute: 314
# Current time: 6:14 on 1/1
# Dispatch logic at 6:14 on 1/1
# Processing minute: 315
# Current time: 6:15 on 1/1
# Dispatch logic at 6:15 on 1/1
# Processing minute: 316
# Current time: 6:16 on 1/1
# Dispatch logic at 6:16 on 1/1
# Processing minute: 317
# Current time: 6:17 on 1/1
# Dispatch logic at 6:17 on 1/1
# Processing minute: 318
# Current time: 6:18 on 1/1
# Dispatch logic at 6:18 on 1/1
# Processing minute: 319
# Current time: 6:19 on 1/1
# Dispatch logic at 6:19 on 1/1
# Processing minute: 320
# Current time: 6:20 on 1/1
# Dispatch logic at 6:20 on 1/1
# Processing minute: 321
# Current time: 6:21 on 1/1
# Dispatch logic at 6:21 on 1/1
# Processing minute: 322
# Current time: 6:22 on 1/1
# Dispatch logic at 6:22 on 1/1
# Processing minute: 323
# Current time: 6:23 on 1/1
# Dispatch logic at 6:23 on 1/1
# Processing minute: 324
# Current time: 6:24 on 1/1
# Dispatch logic at 6:24 on 1/1
# Processing minute: 325
# Current time: 6:25 on 1/1
# Dispatch logic at 6:25 on 1/1
# Processing minute: 326
# Current time: 6:26 on 1/1
# Dispatch logic at 6:26 on 1/1
# Processing minute: 327
# Current time: 6:27 on 1/1
# Dispatch logic at 6:27 on 1/1
# Processing minute: 328
# Current time: 6:28 on 1/1
# Dispatch logic at 6:28 on 1/1
# Processing minute: 329
# Current time: 6:29 on 1/1
# Dispatch logic at 6:29 on 1/1
# Processing minute: 330
# Current time: 6:30 on 1/1
# Dispatch logic at 6:30 on 1/1
# Processing minute: 331
# Current time: 6:31 on 1/1
# Dispatch logic at 6:31 on 1/1
# Processing minute: 332
# Current time: 6:32 on 1/1
# Dispatch logic at 6:32 on 1/1
# Processing minute: 333
# Current time: 6:33 on 1/1
# Dispatch logic at 6:33 on 1/1
# Processing minute: 334
# Current time: 6:34 on 1/1
# Dispatch logic at 6:34 on 1/1
# Processing minute: 335
# Current time: 6:35 on 1/1
# Dispatch logic at 6:35 on 1/1
# Processing minute: 336
# Current time: 6:36 on 1/1
# Dispatch logic at 6:36 on 1/1
# Processing minute: 337
# Current time: 6:37 on 1/1
# Dispatch logic at 6:37 on 1/1
# Processing minute: 338
# Current time: 6:38 on 1/1
# Dispatch logic at 6:38 on 1/1
# Processing minute: 339
# Current time: 6:39 on 1/1
# Dispatch logic at 6:39 on 1/1
# Processing minute: 340
# Current time: 6:40 on 1/1
# Dispatch logic at 6:40 on 1/1
# Processing minute: 341
# Current time: 6:41 on 1/1
# Dispatch logic at 6:41 on 1/1
# Processing minute: 342
# Current time: 6:42 on 1/1
# Dispatch logic at 6:42 on 1/1
# Processing minute: 343
# Current time: 6:43 on 1/1
# Dispatch logic at 6:43 on 1/1
# Processing minute: 344
# Current time: 6:44 on 1/1
# Dispatch logic at 6:44 on 1/1
# Processing minute: 345
# Current time: 6:45 on 1/1
# Dispatch logic at 6:45 on 1/1
# Processing minute: 346
# Current time: 6:46 on 1/1
# Dispatch logic at 6:46 on 1/1
# Processing minute: 347
# Current time: 6:47 on 1/1
# Dispatch logic at 6:47 on 1/1
# Processing minute: 348
# Current time: 6:48 on 1/1
# Dispatch logic at 6:48 on 1/1
# Processing minute: 349
# Current time: 6:49 on 1/1
# Dispatch logic at 6:49 on 1/1
# Processing minute: 350
# Current time: 6:50 on 1/1
# Dispatch logic at 6:50 on 1/1
# Processing minute: 351
# Current time: 6:51 on 1/1
# Dispatch logic at 6:51 on 1/1
# Processing minute: 352
# Current time: 6:52 on 1/1
# Dispatch logic at 6:52 on 1/1
# Processing minute: 353
# Current time: 6:53 on 1/1
# Dispatch logic at 6:53 on 1/1
# Processing minute: 354
# Current time: 6:54 on 1/1
# Dispatch logic at 6:54 on 1/1
# Processing minute: 355
# Current time: 6:55 on 1/1
# Dispatch logic at 6:55 on 1/1
# Processing minute: 356
# Current time: 6:56 on 1/1
# Dispatch logic at 6:56 on 1/1
# Processing minute: 357
# Current time: 6:57 on 1/1
# Dispatch logic at 6:57 on 1/1
# Processing minute: 358
# Current time: 6:58 on 1/1
# Dispatch logic at 6:58 on 1/1
# Processing minute: 359
# Current time: 6:59 on 1/1
# Dispatch logic at 6:59 on 1/1
# Processing minute: 360
# Current time: 7:00 on 1/1
# Dispatch logic at 7:00 on 1/1
# Processing minute: 361
# Current time: 7:01 on 1/1
# Dispatch logic at 7:01 on 1/1
# Processing minute: 362
# Current time: 7:02 on 1/1
# Dispatch logic at 7:02 on 1/1
# Processing minute: 363
# Current time: 7:03 on 1/1
# Dispatch logic at 7:03 on 1/1
# Processing minute: 364
# Current time: 7:04 on 1/1
# Dispatch logic at 7:04 on 1/1
# Processing minute: 365
# Current time: 7:05 on 1/1
# Dispatch logic at 7:05 on 1/1
# Processing minute: 366
# Current time: 7:06 on 1/1
# Dispatch logic at 7:06 on 1/1
# Processing minute: 367
# Current time: 7:07 on 1/1
# Dispatch logic at 7:07 on 1/1
# Processing minute: 368
# Current time: 7:08 on 1/1
# Dispatch logic at 7:08 on 1/1
# Processing minute: 369
# Current time: 7:09 on 1/1
# Dispatch logic at 7:09 on 1/1
# Processing minute: 370
# Current time: 7:10 on 1/1
# Dispatch logic at 7:10 on 1/1
# Processing minute: 371
# Current time: 7:11 on 1/1
# Dispatch logic at 7:11 on 1/1
# Processing minute: 372
# Current time: 7:12 on 1/1
# Dispatch logic at 7:12 on 1/1
# Processing minute: 373
# Current time: 7:13 on 1/1
# Dispatch logic at 7:13 on 1/1
# Processing minute: 374
# Current time: 7:14 on 1/1
# Dispatch logic at 7:14 on 1/1
# Processing minute: 375
# Current time: 7:15 on 1/1
# Dispatch logic at 7:15 on 1/1
# Processing minute: 376
# Current time: 7:16 on 1/1
# Dispatch logic at 7:16 on 1/1
# Processing minute: 377
# Current time: 7:17 on 1/1
# Dispatch logic at 7:17 on 1/1
# Processing minute: 378
# Current time: 7:18 on 1/1
# Dispatch logic at 7:18 on 1/1
# Processing minute: 379
# Current time: 7:19 on 1/1
# Dispatch logic at 7:19 on 1/1
# Processing minute: 380
# Current time: 7:20 on 1/1
# Dispatch logic at 7:20 on 1/1
# Processing minute: 381
# Current time: 7:21 on 1/1
# Dispatch logic at 7:21 on 1/1
# Processing minute: 382
# Current time: 7:22 on 1/1
# Dispatch logic at 7:22 on 1/1
# Processing minute: 383
# Current time: 7:23 on 1/1
# Dispatch logic at 7:23 on 1/1
# Processing minute: 384
# Current time: 7:24 on 1/1
# Dispatch logic at 7:24 on 1/1
# Processing minute: 385
# Current time: 7:25 on 1/1
# Dispatch logic at 7:25 on 1/1
# Processing minute: 386
# Current time: 7:26 on 1/1
# Dispatch logic at 7:26 on 1/1
# Processing minute: 387
# Current time: 7:27 on 1/1
# Dispatch logic at 7:27 on 1/1
# Processing minute: 388
# Current time: 7:28 on 1/1
# Dispatch logic at 7:28 on 1/1
# Processing minute: 389
# Current time: 7:29 on 1/1
# Dispatch logic at 7:29 on 1/1
# Processing minute: 390
# Current time: 7:30 on 1/1
# Dispatch logic at 7:30 on 1/1
# Processing minute: 391
# Current time: 7:31 on 1/1
# Dispatch logic at 7:31 on 1/1
# Processing minute: 392
# Current time: 7:32 on 1/1
# Dispatch logic at 7:32 on 1/1
# Processing minute: 393
# Current time: 7:33 on 1/1
# Dispatch logic at 7:33 on 1/1
# Processing minute: 394
# Current time: 7:34 on 1/1
# Dispatch logic at 7:34 on 1/1
# Processing minute: 395
# Current time: 7:35 on 1/1
# Dispatch logic at 7:35 on 1/1
# Processing minute: 396
# Current time: 7:36 on 1/1
# Dispatch logic at 7:36 on 1/1
# Processing minute: 397
# Current time: 7:37 on 1/1
# Dispatch logic at 7:37 on 1/1
# Processing minute: 398
# Current time: 7:38 on 1/1
# Dispatch logic at 7:38 on 1/1
# Processing minute: 399
# Current time: 7:39 on 1/1
# Dispatch logic at 7:39 on 1/1
# Processing minute: 400
# Current time: 7:40 on 1/1
# Dispatch logic at 7:40 on 1/1
# Processing minute: 401
# Current time: 7:41 on 1/1
# Dispatch logic at 7:41 on 1/1
# Processing minute: 402
# Current time: 7:42 on 1/1
# Dispatch logic at 7:42 on 1/1
# Processing minute: 403
# Current time: 7:43 on 1/1
# Dispatch logic at 7:43 on 1/1
# Processing minute: 404
# Current time: 7:44 on 1/1
# Dispatch logic at 7:44 on 1/1
# Processing minute: 405
# Current time: 7:45 on 1/1
# Dispatch logic at 7:45 on 1/1
# Processing minute: 406
# Current time: 7:46 on 1/1
# Dispatch logic at 7:46 on 1/1
# Processing minute: 407
# Current time: 7:47 on 1/1
# Dispatch logic at 7:47 on 1/1
# Processing minute: 408
# Current time: 7:48 on 1/1
# Dispatch logic at 7:48 on 1/1
# Processing minute: 409
# Current time: 7:49 on 1/1
# Dispatch logic at 7:49 on 1/1
# Processing minute: 410
# Current time: 7:50 on 1/1
# Dispatch logic at 7:50 on 1/1
# Processing minute: 411
# Current time: 7:51 on 1/1
# Dispatch logic at 7:51 on 1/1
# Processing minute: 412
# Current time: 7:52 on 1/1
# Dispatch logic at 7:52 on 1/1
# Processing minute: 413
# Current time: 7:53 on 1/1
# Dispatch logic at 7:53 on 1/1
# Processing minute: 414
# Current time: 7:54 on 1/1
# Dispatch logic at 7:54 on 1/1
# Processing minute: 415
# Current time: 7:55 on 1/1
# Dispatch logic at 7:55 on 1/1
# Processing minute: 416
# Current time: 7:56 on 1/1
# Dispatch logic at 7:56 on 1/1
# Processing minute: 417
# Current time: 7:57 on 1/1
# Dispatch logic at 7:57 on 1/1
# Processing minute: 418
# Current time: 7:58 on 1/1
# Dispatch logic at 7:58 on 1/1
# Processing minute: 419
# Current time: 7:59 on 1/1
# Dispatch logic at 7:59 on 1/1
# Processing minute: 420
# Current time: 8:00 on 1/1
# Dispatch logic at 8:00 on 1/1
# Processing minute: 421
# Current time: 8:01 on 1/1
# Dispatch logic at 8:01 on 1/1
# Processing minute: 422
# Current time: 8:02 on 1/1
# Dispatch logic at 8:02 on 1/1
# Processing minute: 423
# Current time: 8:03 on 1/1
# Dispatch logic at 8:03 on 1/1
# Processing minute: 424
# Current time: 8:04 on 1/1
# Dispatch logic at 8:04 on 1/1
# Processing minute: 425
# Current time: 8:05 on 1/1
# Dispatch logic at 8:05 on 1/1
# Processing minute: 426
# Current time: 8:06 on 1/1
# Dispatch logic at 8:06 on 1/1
# Processing minute: 427
# Current time: 8:07 on 1/1
# Dispatch logic at 8:07 on 1/1
# Processing minute: 428
# Current time: 8:08 on 1/1
# Dispatch logic at 8:08 on 1/1
# Processing minute: 429
# Current time: 8:09 on 1/1
# Dispatch logic at 8:09 on 1/1
# Processing minute: 430
# Current time: 8:10 on 1/1
# Dispatch logic at 8:10 on 1/1
# Processing minute: 431
# Current time: 8:11 on 1/1
# Dispatch logic at 8:11 on 1/1
# Processing minute: 432
# Current time: 8:12 on 1/1
# Dispatch logic at 8:12 on 1/1
# Processing minute: 433
# Current time: 8:13 on 1/1
# Dispatch logic at 8:13 on 1/1
# Processing minute: 434
# Current time: 8:14 on 1/1
# Dispatch logic at 8:14 on 1/1
# Processing minute: 435
# Current time: 8:15 on 1/1
# Dispatch logic at 8:15 on 1/1
# Processing minute: 436
# Current time: 8:16 on 1/1
# Dispatch logic at 8:16 on 1/1
# Processing minute: 437
# Current time: 8:17 on 1/1
# Dispatch logic at 8:17 on 1/1
# Processing minute: 438
# Current time: 8:18 on 1/1
# Dispatch logic at 8:18 on 1/1
# Processing minute: 439
# Current time: 8:19 on 1/1
# Dispatch logic at 8:19 on 1/1
# Processing minute: 440
# Current time: 8:20 on 1/1
# Dispatch logic at 8:20 on 1/1
# Processing minute: 441
# Current time: 8:21 on 1/1
# Dispatch logic at 8:21 on 1/1
# Processing minute: 442
# Current time: 8:22 on 1/1
# Dispatch logic at 8:22 on 1/1
# Processing minute: 443
# Current time: 8:23 on 1/1
# Dispatch logic at 8:23 on 1/1
# Processing minute: 444
# Current time: 8:24 on 1/1
# Dispatch logic at 8:24 on 1/1
# Processing minute: 445
# Current time: 8:25 on 1/1
# Dispatch logic at 8:25 on 1/1
# Processing minute: 446
# Current time: 8:26 on 1/1
# Dispatch logic at 8:26 on 1/1
# Processing minute: 447
# Current time: 8:27 on 1/1
# Dispatch logic at 8:27 on 1/1
# Processing minute: 448
# Current time: 8:28 on 1/1
# Dispatch logic at 8:28 on 1/1
# Processing minute: 449
# Current time: 8:29 on 1/1
# Dispatch logic at 8:29 on 1/1
# Processing minute: 450
# Current time: 8:30 on 1/1
# Dispatch logic at 8:30 on 1/1
# Processing minute: 451
# Current time: 8:31 on 1/1
# Dispatch logic at 8:31 on 1/1
# Processing minute: 452
# Current time: 8:32 on 1/1
# Dispatch logic at 8:32 on 1/1
# Processing minute: 453
# Current time: 8:33 on 1/1
# Dispatch logic at 8:33 on 1/1
# Processing minute: 454
# Current time: 8:34 on 1/1
# Dispatch logic at 8:34 on 1/1
# Processing minute: 455
# Current time: 8:35 on 1/1
# Dispatch logic at 8:35 on 1/1
# Processing minute: 456
# Current time: 8:36 on 1/1
# Dispatch logic at 8:36 on 1/1
# Processing minute: 457
# Current time: 8:37 on 1/1
# Dispatch logic at 8:37 on 1/1
# Processing minute: 458
# Current time: 8:38 on 1/1
# Dispatch logic at 8:38 on 1/1
# Processing minute: 459
# Current time: 8:39 on 1/1
# Dispatch logic at 8:39 on 1/1
# Processing minute: 460
# Current time: 8:40 on 1/1
# Dispatch logic at 8:40 on 1/1
# Processing minute: 461
# Current time: 8:41 on 1/1
# Dispatch logic at 8:41 on 1/1
# Processing minute: 462
# Current time: 8:42 on 1/1
# Dispatch logic at 8:42 on 1/1
# Processing minute: 463
# Current time: 8:43 on 1/1
# Dispatch logic at 8:43 on 1/1
# Processing minute: 464
# Current time: 8:44 on 1/1
# Dispatch logic at 8:44 on 1/1
# Processing minute: 465
# Current time: 8:45 on 1/1
# Dispatch logic at 8:45 on 1/1
# Processing minute: 466
# Current time: 8:46 on 1/1
# Dispatch logic at 8:46 on 1/1
# Processing minute: 467
# Current time: 8:47 on 1/1
# Dispatch logic at 8:47 on 1/1
# Processing minute: 468
# Current time: 8:48 on 1/1
# Dispatch logic at 8:48 on 1/1
# Processing minute: 469
# Current time: 8:49 on 1/1
# Dispatch logic at 8:49 on 1/1
# Processing minute: 470
# Current time: 8:50 on 1/1
# Dispatch logic at 8:50 on 1/1
# Processing minute: 471
# Current time: 8:51 on 1/1
# Dispatch logic at 8:51 on 1/1
# Processing minute: 472
# Current time: 8:52 on 1/1
# Dispatch logic at 8:52 on 1/1
# Processing minute: 473
# Current time: 8:53 on 1/1
# Dispatch logic at 8:53 on 1/1
# Processing minute: 474
# Current time: 8:54 on 1/1
# Dispatch logic at 8:54 on 1/1
# Processing minute: 475
# Current time: 8:55 on 1/1
# Dispatch logic at 8:55 on 1/1
# Processing minute: 476
# Current time: 8:56 on 1/1
# Dispatch logic at 8:56 on 1/1
# Processing minute: 477
# Current time: 8:57 on 1/1
# Dispatch logic at 8:57 on 1/1
# Processing minute: 478
# Current time: 8:58 on 1/1
# Dispatch logic at 8:58 on 1/1
# Processing minute: 479
# Current time: 8:59 on 1/1
# Dispatch logic at 8:59 on 1/1
# Processing minute: 480
# Current time: 9:00 on 1/1
# Dispatch logic at 9:00 on 1/1
# Processing minute: 481
# Current time: 9:01 on 1/1
# Dispatch logic at 9:01 on 1/1
# Processing minute: 482
# Current time: 9:02 on 1/1
# Dispatch logic at 9:02 on 1/1
# Processing minute: 483
# Current time: 9:03 on 1/1
# Dispatch logic at 9:03 on 1/1
# Processing minute: 484
# Current time: 9:04 on 1/1
# Dispatch logic at 9:04 on 1/1
# Processing minute: 485
# Current time: 9:05 on 1/1
# Dispatch logic at 9:05 on 1/1
# Processing minute: 486
# Current time: 9:06 on 1/1
# Dispatch logic at 9:06 on 1/1
# Processing minute: 487
# Current time: 9:07 on 1/1
# Dispatch logic at 9:07 on 1/1
# Processing minute: 488
# Current time: 9:08 on 1/1
# Dispatch logic at 9:08 on 1/1
# Processing minute: 489
# Current time: 9:09 on 1/1
# Dispatch logic at 9:09 on 1/1
# Processing minute: 490
# Current time: 9:10 on 1/1
# Dispatch logic at 9:10 on 1/1
# Processing minute: 491
# Current time: 9:11 on 1/1
# Dispatch logic at 9:11 on 1/1
# Processing minute: 492
# Current time: 9:12 on 1/1
# Dispatch logic at 9:12 on 1/1
# Processing minute: 493
# Current time: 9:13 on 1/1
# Dispatch logic at 9:13 on 1/1
# Processing minute: 494
# Current time: 9:14 on 1/1
# Dispatch logic at 9:14 on 1/1
# Processing minute: 495
# Current time: 9:15 on 1/1
# Dispatch logic at 9:15 on 1/1
# Processing minute: 496
# Current time: 9:16 on 1/1
# Dispatch logic at 9:16 on 1/1
# Processing minute: 497
# Current time: 9:17 on 1/1
# Dispatch logic at 9:17 on 1/1
# Processing minute: 498
# Current time: 9:18 on 1/1
# Dispatch logic at 9:18 on 1/1
# Processing minute: 499
# Current time: 9:19 on 1/1
# Dispatch logic at 9:19 on 1/1
# Processing minute: 500
# Current time: 9:20 on 1/1
# Dispatch logic at 9:20 on 1/1
# Processing minute: 501
# Current time: 9:21 on 1/1
# Dispatch logic at 9:21 on 1/1
# Processing minute: 502
# Current time: 9:22 on 1/1
# Dispatch logic at 9:22 on 1/1
# Processing minute: 503
# Current time: 9:23 on 1/1
# Dispatch logic at 9:23 on 1/1
# Processing minute: 504
# Current time: 9:24 on 1/1
# Dispatch logic at 9:24 on 1/1
# Processing minute: 505
# Current time: 9:25 on 1/1
# Dispatch logic at 9:25 on 1/1
# Processing minute: 506
# Current time: 9:26 on 1/1
# Dispatch logic at 9:26 on 1/1
# Processing minute: 507
# Current time: 9:27 on 1/1
# Dispatch logic at 9:27 on 1/1
# Processing minute: 508
# Current time: 9:28 on 1/1
# Dispatch logic at 9:28 on 1/1
# Processing minute: 509
# Current time: 9:29 on 1/1
# Dispatch logic at 9:29 on 1/1
# Processing minute: 510
# Current time: 9:30 on 1/1
# Dispatch logic at 9:30 on 1/1
# Processing minute: 511
# Current time: 9:31 on 1/1
# Dispatch logic at 9:31 on 1/1
# Processing minute: 512
# Current time: 9:32 on 1/1
# Dispatch logic at 9:32 on 1/1
# Processing minute: 513
# Current time: 9:33 on 1/1
# Dispatch logic at 9:33 on 1/1
# Processing minute: 514
# Current time: 9:34 on 1/1
# Dispatch logic at 9:34 on 1/1
# Processing minute: 515
# Current time: 9:35 on 1/1
# Dispatch logic at 9:35 on 1/1
# Processing minute: 516
# Current time: 9:36 on 1/1
# Dispatch logic at 9:36 on 1/1
# Processing minute: 517
# Current time: 9:37 on 1/1
# Dispatch logic at 9:37 on 1/1
# Processing minute: 518
# Current time: 9:38 on 1/1
# Dispatch logic at 9:38 on 1/1
# Processing minute: 519
# Current time: 9:39 on 1/1
# Dispatch logic at 9:39 on 1/1
# Processing minute: 520
# Current time: 9:40 on 1/1
# Dispatch logic at 9:40 on 1/1
# New orders at 9:40 - 1 new orders
# Order 12 for customer 72 at location (1175, 400) - expected journey time: 7.88 minutes - 4 robots available
# Order 12 for customer 72 at location (1175, 400) - distance: 561.81 - tasked to Togo expected arrival time: 587.88 minutes
# Processing minute: 521
# Current time: 9:41 on 1/1
# Dispatch logic at 9:41 on 1/1
# Processing minute: 522
# Current time: 9:42 on 1/1
# Dispatch logic at 9:42 on 1/1
# Processing minute: 523
# Current time: 9:43 on 1/1
# Dispatch logic at 9:43 on 1/1
# Processing minute: 524
# Current time: 9:44 on 1/1
# Dispatch logic at 9:44 on 1/1
# Processing minute: 525
# Current time: 9:45 on 1/1
# Dispatch logic at 9:45 on 1/1
# New orders at 9:45 - 1 new orders
# Order 1 for customer 11 at location (500, 1625) - expected journey time: 13.14 minutes - no robots available
# Processing minute: 526
# Current time: 9:46 on 1/1
# Dispatch logic at 9:46 on 1/1
# Processing minute: 527
# Current time: 9:47 on 1/1
# Dispatch logic at 9:47 on 1/1
# Processing minute: 528
# Current time: 9:48 on 1/1
# Dispatch logic at 9:48 on 1/1
# Processing minute: 529
# Current time: 9:49 on 1/1
# Dispatch logic at 9:49 on 1/1
# Processing minute: 530
# Current time: 9:50 on 1/1
# Dispatch logic at 9:50 on 1/1
# Processing minute: 531
# Current time: 9:51 on 1/1
# Dispatch logic at 9:51 on 1/1
# Processing minute: 532
# Current time: 9:52 on 1/1
# Dispatch logic at 9:52 on 1/1
# Processing minute: 533
# Current time: 9:53 on 1/1
# Dispatch logic at 9:53 on 1/1
# Processing minute: 534
# Current time: 9:54 on 1/1
# Dispatch logic at 9:54 on 1/1
# Processing minute: 535
# Current time: 9:55 on 1/1
# Dispatch logic at 9:55 on 1/1
# Processing minute: 536
# Current time: 9:56 on 1/1
# Dispatch logic at 9:56 on 1/1
# Processing minute: 537
# Current time: 9:57 on 1/1
# Dispatch logic at 9:57 on 1/1
# Processing minute: 538
# Current time: 9:58 on 1/1
# Dispatch logic at 9:58 on 1/1
# Processing minute: 539
# Current time: 9:59 on 1/1
# Dispatch logic at 9:59 on 1/1
# Processing minute: 540
# Current time: 10:00 on 1/1
# Dispatch logic at 10:00 on 1/1
# Processing minute: 541
# Current time: 10:01 on 1/1
# Dispatch logic at 10:01 on 1/1
# Processing minute: 542
# Current time: 10:02 on 1/1
# Dispatch logic at 10:02 on 1/1
# Processing minute: 543
# Current time: 10:03 on 1/1
# Dispatch logic at 10:03 on 1/1
# Processing minute: 544
# Current time: 10:04 on 1/1
# Dispatch logic at 10:04 on 1/1
# Processing minute: 545
# Current time: 10:05 on 1/1
# Dispatch logic at 10:05 on 1/1
# Processing minute: 546
# Current time: 10:06 on 1/1
# Dispatch logic at 10:06 on 1/1
# Processing minute: 547
# Current time: 10:07 on 1/1
# Dispatch logic at 10:07 on 1/1
# Processing minute: 548
# Current time: 10:08 on 1/1
# Dispatch logic at 10:08 on 1/1
# Processing minute: 549
# Current time: 10:09 on 1/1
# Dispatch logic at 10:09 on 1/1
# Processing minute: 550
# Current time: 10:10 on 1/1
# Dispatch logic at 10:10 on 1/1
# Processing minute: 551
# Current time: 10:11 on 1/1
# Dispatch logic at 10:11 on 1/1
# Processing minute: 552
# Current time: 10:12 on 1/1
# Dispatch logic at 10:12 on 1/1
# Processing minute: 553
# Current time: 10:13 on 1/1
# Dispatch logic at 10:13 on 1/1
# Processing minute: 554
# Current time: 10:14 on 1/1
# Dispatch logic at 10:14 on 1/1
# Processing minute: 555
# Current time: 10:15 on 1/1
# Dispatch logic at 10:15 on 1/1
# Processing minute: 556
# Current time: 10:16 on 1/1
# Dispatch logic at 10:16 on 1/1
# Processing minute: 557
# Current time: 10:17 on 1/1
# Dispatch logic at 10:17 on 1/1
# Processing minute: 558
# Current time: 10:18 on 1/1
# Dispatch logic at 10:18 on 1/1
# Processing minute: 559
# Current time: 10:19 on 1/1
# Dispatch logic at 10:19 on 1/1
# Processing minute: 560
# Current time: 10:20 on 1/1
# Dispatch logic at 10:20 on 1/1
# Processing minute: 561
# Current time: 10:21 on 1/1
# Dispatch logic at 10:21 on 1/1
# Processing minute: 562
# Current time: 10:22 on 1/1
# Dispatch logic at 10:22 on 1/1
# Processing minute: 563
# Current time: 10:23 on 1/1
# Dispatch logic at 10:23 on 1/1
# Processing minute: 564
# Current time: 10:24 on 1/1
# Dispatch logic at 10:24 on 1/1
# Processing minute: 565
# Current time: 10:25 on 1/1
# Dispatch logic at 10:25 on 1/1
# Processing minute: 566
# Current time: 10:26 on 1/1
# Dispatch logic at 10:26 on 1/1
# Processing minute: 567
# Current time: 10:27 on 1/1
# Dispatch logic at 10:27 on 1/1
# Processing minute: 568
# Current time: 10:28 on 1/1
# Dispatch logic at 10:28 on 1/1
# Processing minute: 569
# Current time: 10:29 on 1/1
# Dispatch logic at 10:29 on 1/1
# Processing minute: 570
# Current time: 10:30 on 1/1
# Dispatch logic at 10:30 on 1/1
# Processing minute: 571
# Current time: 10:31 on 1/1
# Dispatch logic at 10:31 on 1/1
# Processing minute: 572
# Current time: 10:32 on 1/1
# Dispatch logic at 10:32 on 1/1
# Processing minute: 573
# Current time: 10:33 on 1/1
# Dispatch logic at 10:33 on 1/1
# Processing minute: 574
# Current time: 10:34 on 1/1
# Dispatch logic at 10:34 on 1/1
# Processing minute: 575
# Current time: 10:35 on 1/1
# Dispatch logic at 10:35 on 1/1
# New orders at 10:35 - 1 new orders
# Order 0 for customer 9 at location (1375, 1500) - expected journey time: 11.89 minutes - no robots available
# Processing minute: 576
# Current time: 10:36 on 1/1
# Dispatch logic at 10:36 on 1/1
# Processing minute: 577
# Current time: 10:37 on 1/1
# Dispatch logic at 10:37 on 1/1
# Processing minute: 578
# Current time: 10:38 on 1/1
# Dispatch logic at 10:38 on 1/1
# Processing minute: 579
# Current time: 10:39 on 1/1
# Dispatch logic at 10:39 on 1/1
# Processing minute: 580
# Current time: 10:40 on 1/1
# Dispatch logic at 10:40 on 1/1
# Processing minute: 581
# Current time: 10:41 on 1/1
# Dispatch logic at 10:41 on 1/1
# Processing minute: 582
# Current time: 10:42 on 1/1
# Dispatch logic at 10:42 on 1/1
# Processing minute: 583
# Current time: 10:43 on 1/1
# Dispatch logic at 10:43 on 1/1
# Processing minute: 584
# Current time: 10:44 on 1/1
# Dispatch logic at 10:44 on 1/1
# Processing minute: 585
# Current time: 10:45 on 1/1
# Dispatch logic at 10:45 on 1/1
# Processing minute: 586
# Current time: 10:46 on 1/1
# Dispatch logic at 10:46 on 1/1
# Processing minute: 587
# Current time: 10:47 on 1/1
# Dispatch logic at 10:47 on 1/1
# Processing minute: 588
# Current time: 10:48 on 1/1
# Dispatch logic at 10:48 on 1/1
# Processing minute: 589
# Current time: 10:49 on 1/1
# Dispatch logic at 10:49 on 1/1
# Processing minute: 590
# Current time: 10:50 on 1/1
# Dispatch logic at 10:50 on 1/1
# Processing minute: 591
# Current time: 10:51 on 1/1
# Dispatch logic at 10:51 on 1/1
# Processing minute: 592
# Current time: 10:52 on 1/1
# Dispatch logic at 10:52 on 1/1
# Processing minute: 593
# Current time: 10:53 on 1/1
# Dispatch logic at 10:53 on 1/1
# Processing minute: 594
# Current time: 10:54 on 1/1
# Dispatch logic at 10:54 on 1/1
# Processing minute: 595
# Current time: 10:55 on 1/1
# Dispatch logic at 10:55 on 1/1
# Processing minute: 596
# Current time: 10:56 on 1/1
# Dispatch logic at 10:56 on 1/1
# Processing minute: 597
# Current time: 10:57 on 1/1
# Dispatch logic at 10:57 on 1/1
# Processing minute: 598
# Current time: 10:58 on 1/1
# Dispatch logic at 10:58 on 1/1
# Processing minute: 599
# Current time: 10:59 on 1/1
# Dispatch logic at 10:59 on 1/1
# ...
# Processing minute: 1245
# Current time: 21:45 on 1/1
# Dispatch logic at 21:45 on 1/1
# Processing minute: 1246
# Current time: 21:46 on 1/1
# Dispatch logic at 21:46 on 1/1
# Processing minute: 1247
# Current time: 21:47 on 1/1
# Dispatch logic at 21:47 on 1/1
# Processing minute: 1248
# Current time: 21:48 on 1/1
# Dispatch logic at 21:48 on 1/1
# Processing minute: 1249
# Current time: 21:49 on 1/1
# Dispatch logic at 21:49 on 1/1
# Processing minute: 1250
# Current time: 21:50 on 1/1
# Dispatch logic at 21:50 on 1/1
# Processing minute: 1251
# Current time: 21:51 on 1/1
# Dispatch logic at 21:51 on 1/1
# Processing minute: 1252
# Current time: 21:52 on 1/1
# Dispatch logic at 21:52 on 1/1
# Processing minute: 1253
# Current time: 21:53 on 1/1
# Dispatch logic at 21:53 on 1/1
# Processing minute: 1254
# Current time: 21:54 on 1/1
# Dispatch logic at 21:54 on 1/1
# Processing minute: 1255
# Current time: 21:55 on 1/1
# Dispatch logic at 21:55 on 1/1
# Processing minute: 1256
# Current time: 21:56 on 1/1
# Dispatch logic at 21:56 on 1/1
# Processing minute: 1257
# Current time: 21:57 on 1/1
# Dispatch logic at 21:57 on 1/1
# Processing minute: 1258
# Current time: 21:58 on 1/1
# Dispatch logic at 21:58 on 1/1
# Processing minute: 1259
# Current time: 21:59 on 1/1
# Dispatch logic at 21:59 on 1/1
# Processing minute: 1260
# Current time: 22:00 on 1/1
# Dispatch logic at 22:00 on 1/1
# Processing minute: 1261
# Current time: 22:01 on 1/1
# Dispatch logic at 22:01 on 1/1
# Processing minute: 1262
# Current time: 22:02 on 1/1
# Dispatch logic at 22:02 on 1/1
# Processing minute: 1263
# Current time: 22:03 on 1/1
# Dispatch logic at 22:03 on 1/1
# Processing minute: 1264
# Current time: 22:04 on 1/1
# Dispatch logic at 22:04 on 1/1
# Processing minute: 1265
# Current time: 22:05 on 1/1
# Dispatch logic at 22:05 on 1/1
# Processing minute: 1266
# Current time: 22:06 on 1/1
# Dispatch logic at 22:06 on 1/1
# Processing minute: 1267
# Current time: 22:07 on 1/1
# Dispatch logic at 22:07 on 1/1
# Processing minute: 1268
# Current time: 22:08 on 1/1
# Dispatch logic at 22:08 on 1/1
# Processing minute: 1269
# Current time: 22:09 on 1/1
# Dispatch logic at 22:09 on 1/1
# Processing minute: 1270
# Current time: 22:10 on 1/1
# Dispatch logic at 22:10 on 1/1
# Processing minute: 1271
# Current time: 22:11 on 1/1
# Dispatch logic at 22:11 on 1/1
# Processing minute: 1272
# Current time: 22:12 on 1/1
# Dispatch logic at 22:12 on 1/1
# Processing minute: 1273
# Current time: 22:13 on 1/1
# Dispatch logic at 22:13 on 1/1
# Processing minute: 1274
# Current time: 22:14 on 1/1
# Dispatch logic at 22:14 on 1/1
# Processing minute: 1275
# Current time: 22:15 on 1/1
# Dispatch logic at 22:15 on 1/1
# Processing minute: 1276
# Current time: 22:16 on 1/1
# Dispatch logic at 22:16 on 1/1
# Processing minute: 1277
# Current time: 22:17 on 1/1
# Dispatch logic at 22:17 on 1/1
# Processing minute: 1278
# Current time: 22:18 on 1/1
# Dispatch logic at 22:18 on 1/1
# Processing minute: 1279
# Current time: 22:19 on 1/1
# Dispatch logic at 22:19 on 1/1
# Processing minute: 1280
# Current time: 22:20 on 1/1
# Dispatch logic at 22:20 on 1/1
# Processing minute: 1281
# Current time: 22:21 on 1/1
# Dispatch logic at 22:21 on 1/1
# Processing minute: 1282
# Current time: 22:22 on 1/1
# Dispatch logic at 22:22 on 1/1
# Processing minute: 1283
# Current time: 22:23 on 1/1
# Dispatch logic at 22:23 on 1/1
# Processing minute: 1284
# Current time: 22:24 on 1/1
# Dispatch logic at 22:24 on 1/1
# Processing minute: 1285
# Current time: 22:25 on 1/1
# Dispatch logic at 22:25 on 1/1
# Processing minute: 1286
# Current time: 22:26 on 1/1
# Dispatch logic at 22:26 on 1/1
# Processing minute: 1287
# Current time: 22:27 on 1/1
# Dispatch logic at 22:27 on 1/1
# Processing minute: 1288
# Current time: 22:28 on 1/1
# Dispatch logic at 22:28 on 1/1
# Processing minute: 1289
# Current time: 22:29 on 1/1
# Dispatch logic at 22:29 on 1/1
# Processing minute: 1290
# Current time: 22:30 on 1/1
# Dispatch logic at 22:30 on 1/1
# Processing minute: 1291
# Current time: 22:31 on 1/1
# Dispatch logic at 22:31 on 1/1
# Processing minute: 1292
# Current time: 22:32 on 1/1
# Dispatch logic at 22:32 on 1/1
# Processing minute: 1293
# Current time: 22:33 on 1/1
# Dispatch logic at 22:33 on 1/1
# Processing minute: 1294
# Current time: 22:34 on 1/1
# Dispatch logic at 22:34 on 1/1
# Processing minute: 1295
# Current time: 22:35 on 1/1
# Dispatch logic at 22:35 on 1/1
# Processing minute: 1296
# Current time: 22:36 on 1/1
# Dispatch logic at 22:36 on 1/1
# Processing minute: 1297
# Current time: 22:37 on 1/1
# Dispatch logic at 22:37 on 1/1
# Processing minute: 1298
# Current time: 22:38 on 1/1
# Dispatch logic at 22:38 on 1/1
# Processing minute: 1299
# Current time: 22:39 on 1/1
# Dispatch logic at 22:39 on 1/1
# Processing minute: 1300
# Current time: 22:40 on 1/1
# Dispatch logic at 22:40 on 1/1
# Processing minute: 1301
# Current time: 22:41 on 1/1
# Dispatch logic at 22:41 on 1/1
# Processing minute: 1302
# Current time: 22:42 on 1/1
# Dispatch logic at 22:42 on 1/1
# Processing minute: 1303
# Current time: 22:43 on 1/1
# Dispatch logic at 22:43 on 1/1
# Processing minute: 1304
# Current time: 22:44 on 1/1
# Dispatch logic at 22:44 on 1/1
# Processing minute: 1305
# Current time: 22:45 on 1/1
# Dispatch logic at 22:45 on 1/1
# Processing minute: 1306
# Current time: 22:46 on 1/1
# Dispatch logic at 22:46 on 1/1
# Processing minute: 1307
# Current time: 22:47 on 1/1
# Dispatch logic at 22:47 on 1/1
# Processing minute: 1308
# Current time: 22:48 on 1/1
# Dispatch logic at 22:48 on 1/1
# Processing minute: 1309
# Current time: 22:49 on 1/1
# Dispatch logic at 22:49 on 1/1
# Processing minute: 1310
# Current time: 22:50 on 1/1
# Dispatch logic at 22:50 on 1/1
# Processing minute: 1311
# Current time: 22:51 on 1/1
# Dispatch logic at 22:51 on 1/1
# Processing minute: 1312
# Current time: 22:52 on 1/1
# Dispatch logic at 22:52 on 1/1
# Processing minute: 1313
# Current time: 22:53 on 1/1
# Dispatch logic at 22:53 on 1/1
# Processing minute: 1314
# Current time: 22:54 on 1/1
# Dispatch logic at 22:54 on 1/1
# Processing minute: 1315
# Current time: 22:55 on 1/1
# Dispatch logic at 22:55 on 1/1
# Processing minute: 1316
# Current time: 22:56 on 1/1
# Dispatch logic at 22:56 on 1/1
# Processing minute: 1317
# Current time: 22:57 on 1/1
# Dispatch logic at 22:57 on 1/1
# Processing minute: 1318
# Current time: 22:58 on 1/1
# Dispatch logic at 22:58 on 1/1
# Processing minute: 1319
# Current time: 22:59 on 1/1
# Dispatch logic at 22:59 on 1/1
# Processing minute: 1320
# Current time: 23:00 on 1/1
# Dispatch logic at 23:00 on 1/1
# Processing minute: 1321
# Current time: 23:01 on 1/1
# Dispatch logic at 23:01 on 1/1
# Processing minute: 1322
# Current time: 23:02 on 1/1
# Dispatch logic at 23:02 on 1/1
# Processing minute: 1323
# Current time: 23:03 on 1/1
# Dispatch logic at 23:03 on 1/1
# Processing minute: 1324
# Current time: 23:04 on 1/1
# Dispatch logic at 23:04 on 1/1
# Processing minute: 1325
# Current time: 23:05 on 1/1
# Dispatch logic at 23:05 on 1/1
# Processing minute: 1326
# Current time: 23:06 on 1/1
# Dispatch logic at 23:06 on 1/1
# Processing minute: 1327
# Current time: 23:07 on 1/1
# Dispatch logic at 23:07 on 1/1
# Processing minute: 1328
# Current time: 23:08 on 1/1
# Dispatch logic at 23:08 on 1/1
# Processing minute: 1329
# Current time: 23:09 on 1/1
# Dispatch logic at 23:09 on 1/1
# Processing minute: 1330
# Current time: 23:10 on 1/1
# Dispatch logic at 23:10 on 1/1
# Processing minute: 1331
# Current time: 23:11 on 1/1
# Dispatch logic at 23:11 on 1/1
# Processing minute: 1332
# Current time: 23:12 on 1/1
# Dispatch logic at 23:12 on 1/1
# Processing minute: 1333
# Current time: 23:13 on 1/1
# Dispatch logic at 23:13 on 1/1
# Processing minute: 1334
# Current time: 23:14 on 1/1
# Dispatch logic at 23:14 on 1/1
# Processing minute: 1335
# Current time: 23:15 on 1/1
# Dispatch logic at 23:15 on 1/1
# Processing minute: 1336
# Current time: 23:16 on 1/1
# Dispatch logic at 23:16 on 1/1
# Processing minute: 1337
# Current time: 23:17 on 1/1
# Dispatch logic at 23:17 on 1/1
# Processing minute: 1338
# Current time: 23:18 on 1/1
# Dispatch logic at 23:18 on 1/1
# Processing minute: 1339
# Current time: 23:19 on 1/1
# Dispatch logic at 23:19 on 1/1
# Processing minute: 1340
# Current time: 23:20 on 1/1
# Dispatch logic at 23:20 on 1/1
# Processing minute: 1341
# Current time: 23:21 on 1/1
# Dispatch logic at 23:21 on 1/1
# Processing minute: 1342
# Current time: 23:22 on 1/1
# Dispatch logic at 23:22 on 1/1
# Processing minute: 1343
# Current time: 23:23 on 1/1
# Dispatch logic at 23:23 on 1/1
# Processing minute: 1344
# Current time: 23:24 on 1/1
# Dispatch logic at 23:24 on 1/1
# Processing minute: 1345
# Current time: 23:25 on 1/1
# Dispatch logic at 23:25 on 1/1
# Processing minute: 1346
# Current time: 23:26 on 1/1
# Dispatch logic at 23:26 on 1/1
# Processing minute: 1347
# Current time: 23:27 on 1/1
# Dispatch logic at 23:27 on 1/1
# Processing minute: 1348
# Current time: 23:28 on 1/1
# Dispatch logic at 23:28 on 1/1
# Processing minute: 1349
# Current time: 23:29 on 1/1
# Dispatch logic at 23:29 on 1/1
# Processing minute: 1350
# Current time: 23:30 on 1/1
# Dispatch logic at 23:30 on 1/1
# Processing minute: 1351
# Current time: 23:31 on 1/1
# Dispatch logic at 23:31 on 1/1
# Processing minute: 1352
# Current time: 23:32 on 1/1
# Dispatch logic at 23:32 on 1/1
# Processing minute: 1353
# Current time: 23:33 on 1/1
# Dispatch logic at 23:33 on 1/1
# Processing minute: 1354
# Current time: 23:34 on 1/1
# Dispatch logic at 23:34 on 1/1
# Processing minute: 1355
# Current time: 23:35 on 1/1
# Dispatch logic at 23:35 on 1/1
# Processing minute: 1356
# Current time: 23:36 on 1/1
# Dispatch logic at 23:36 on 1/1
# Processing minute: 1357
# Current time: 23:37 on 1/1
# Dispatch logic at 23:37 on 1/1
# Processing minute: 1358
# Current time: 23:38 on 1/1
# Dispatch logic at 23:38 on 1/1
# Processing minute: 1359
# Current time: 23:39 on 1/1
# Dispatch logic at 23:39 on 1/1
# Processing minute: 1360
# Current time: 23:40 on 1/1
# Dispatch logic at 23:40 on 1/1
# Processing minute: 1361
# Current time: 23:41 on 1/1
# Dispatch logic at 23:41 on 1/1
# Processing minute: 1362
# Current time: 23:42 on 1/1
# Dispatch logic at 23:42 on 1/1
# Processing minute: 1363
# Current time: 23:43 on 1/1
# Dispatch logic at 23:43 on 1/1
# Processing minute: 1364
# Current time: 23:44 on 1/1
# Dispatch logic at 23:44 on 1/1
# Processing minute: 1365
# Current time: 23:45 on 1/1
# Dispatch logic at 23:45 on 1/1
# Processing minute: 1366
# Current time: 23:46 on 1/1
# Dispatch logic at 23:46 on 1/1
# Processing minute: 1367
# Current time: 23:47 on 1/1
# Dispatch logic at 23:47 on 1/1
# Processing minute: 1368
# Current time: 23:48 on 1/1
# Dispatch logic at 23:48 on 1/1
# Processing minute: 1369
# Current time: 23:49 on 1/1
# Dispatch logic at 23:49 on 1/1
# Processing minute: 1370
# Current time: 23:50 on 1/1
# Dispatch logic at 23:50 on 1/1
# Processing minute: 1371
# Current time: 23:51 on 1/1
# Dispatch logic at 23:51 on 1/1
# Processing minute: 1372
# Current time: 23:52 on 1/1
# Dispatch logic at 23:52 on 1/1
# Processing minute: 1373
# Current time: 23:53 on 1/1
# Dispatch logic at 23:53 on 1/1
# Processing minute: 1374
# Current time: 23:54 on 1/1
# Dispatch logic at 23:54 on 1/1
# Processing minute: 1375
# Current time: 23:55 on 1/1
# Dispatch logic at 23:55 on 1/1
# Processing minute: 1376
# Current time: 23:56 on 1/1
# Dispatch logic at 23:56 on 1/1
# Processing minute: 1377
# Current time: 23:57 on 1/1
# Dispatch logic at 23:57 on 1/1
# Processing minute: 1378
# Current time: 23:58 on 1/1
# Dispatch logic at 23:58 on 1/1
# Processing minute: 1379
# Current time: 23:59 on 1/1
# Dispatch logic at 23:59 on 1/1
# Processing minute: 1380
# Current time: 24:00 on 1/1
# Dispatch logic at 24:00 on 1/1
# Processing minute: 1381
# Current time: 24:01 on 1/1
# Dispatch logic at 24:01 on 1/1
# Processing minute: 1382
# Current time: 24:02 on 1/1
# Dispatch logic at 24:02 on 1/1
# Processing minute: 1383
# Current time: 24:03 on 1/1
# Dispatch logic at 24:03 on 1/1
# Processing minute: 1384
# Current time: 24:04 on 1/1
# Dispatch logic at 24:04 on 1/1
# Processing minute: 1385
# Current time: 24:05 on 1/1
# Dispatch logic at 24:05 on 1/1
# Processing minute: 1386
# Current time: 24:06 on 1/1
# Dispatch logic at 24:06 on 1/1
# Processing minute: 1387
# Current time: 24:07 on 1/1
# Dispatch logic at 24:07 on 1/1
# Processing minute: 1388
# Current time: 24:08 on 1/1
# Dispatch logic at 24:08 on 1/1
# Processing minute: 1389
# Current time: 24:09 on 1/1
# Dispatch logic at 24:09 on 1/1
# Processing minute: 1390
# Current time: 24:10 on 1/1
# Dispatch logic at 24:10 on 1/1
# Processing minute: 1391
# Current time: 24:11 on 1/1
# Dispatch logic at 24:11 on 1/1
# Processing minute: 1392
# Current time: 24:12 on 1/1
# Dispatch logic at 24:12 on 1/1
# Processing minute: 1393
# Current time: 24:13 on 1/1
# Dispatch logic at 24:13 on 1/1
# Processing minute: 1394
# Current time: 24:14 on 1/1
# Dispatch logic at 24:14 on 1/1
# Processing minute: 1395
# Current time: 24:15 on 1/1
# Dispatch logic at 24:15 on 1/1
# Processing minute: 1396
# Current time: 24:16 on 1/1
# Dispatch logic at 24:16 on 1/1
# Processing minute: 1397
# Current time: 24:17 on 1/1
# Dispatch logic at 24:17 on 1/1
# Processing minute: 1398
# Current time: 24:18 on 1/1
# Dispatch logic at 24:18 on 1/1
# Processing minute: 1399
# Current time: 24:19 on 1/1
# Dispatch logic at 24:19 on 1/1
# Processing minute: 1400
# Current time: 24:20 on 1/1
# Dispatch logic at 24:20 on 1/1
# Processing minute: 1401
# Current time: 24:21 on 1/1
# Dispatch logic at 24:21 on 1/1
# Processing minute: 1402
# Current time: 24:22 on 1/1
# Dispatch logic at 24:22 on 1/1
# Processing minute: 1403
# Current time: 24:23 on 1/1
# Dispatch logic at 24:23 on 1/1
# Processing minute: 1404
# Current time: 24:24 on 1/1
# Dispatch logic at 24:24 on 1/1
# Processing minute: 1405
# Current time: 24:25 on 1/1
# Dispatch logic at 24:25 on 1/1
# Processing minute: 1406
# Current time: 24:26 on 1/1
# Dispatch logic at 24:26 on 1/1
# Processing minute: 1407
# Current time: 24:27 on 1/1
# Dispatch logic at 24:27 on 1/1
# Processing minute: 1408
# Current time: 24:28 on 1/1
# Dispatch logic at 24:28 on 1/1
# Processing minute: 1409
# Current time: 24:29 on 1/1
# Dispatch logic at 24:29 on 1/1
# Processing minute: 1410
# Current time: 24:30 on 1/1
# Dispatch logic at 24:30 on 1/1
# Processing minute: 1411
# Current time: 24:31 on 1/1
# Dispatch logic at 24:31 on 1/1
# Processing minute: 1412
# Current time: 24:32 on 1/1
# Dispatch logic at 24:32 on 1/1
# Processing minute: 1413
# Current time: 24:33 on 1/1
# Dispatch logic at 24:33 on 1/1
# Processing minute: 1414
# Current time: 24:34 on 1/1
# Dispatch logic at 24:34 on 1/1
# Processing minute: 1415
# Current time: 24:35 on 1/1
# Dispatch logic at 24:35 on 1/1
# Processing minute: 1416
# Current time: 24:36 on 1/1
# Dispatch logic at 24:36 on 1/1
# Processing minute: 1417
# Current time: 24:37 on 1/1
# Dispatch logic at 24:37 on 1/1
# Processing minute: 1418
# Current time: 24:38 on 1/1
# Dispatch logic at 24:38 on 1/1
# Processing minute: 1419
# Current time: 24:39 on 1/1
# Dispatch logic at 24:39 on 1/1
# Processing minute: 1420
# Current time: 24:40 on 1/1
# Dispatch logic at 24:40 on 1/1
# Processing minute: 1421
# Current time: 24:41 on 1/1
# Dispatch logic at 24:41 on 1/1
# Processing minute: 1422
# Current time: 24:42 on 1/1
# Dispatch logic at 24:42 on 1/1
# Processing minute: 1423
# Current time: 24:43 on 1/1
# Dispatch logic at 24:43 on 1/1
# Processing minute: 1424
# Current time: 24:44 on 1/1
# Dispatch logic at 24:44 on 1/1
# Processing minute: 1425
# Current time: 24:45 on 1/1
# Dispatch logic at 24:45 on 1/1
# Processing minute: 1426
# Current time: 24:46 on 1/1
# Dispatch logic at 24:46 on 1/1
# Processing minute: 1427
# Current time: 24:47 on 1/1
# Dispatch logic at 24:47 on 1/1
# Processing minute: 1428
# Current time: 24:48 on 1/1
# Dispatch logic at 24:48 on 1/1
# Processing minute: 1429
# Current time: 24:49 on 1/1
# Dispatch logic at 24:49 on 1/1
# Processing minute: 1430
# Current time: 24:50 on 1/1
# Dispatch logic at 24:50 on 1/1
# Processing minute: 1431
# Current time: 24:51 on 1/1
# Dispatch logic at 24:51 on 1/1
# Processing minute: 1432
# Current time: 24:52 on 1/1
# Dispatch logic at 24:52 on 1/1
# Processing minute: 1433
# Current time: 24:53 on 1/1
# Dispatch logic at 24:53 on 1/1
# Processing minute: 1434
# Current time: 24:54 on 1/1
# Dispatch logic at 24:54 on 1/1
# Processing minute: 1435
# Current time: 24:55 on 1/1
# Dispatch logic at 24:55 on 1/1
# Processing minute: 1436
# Current time: 24:56 on 1/1
# Dispatch logic at 24:56 on 1/1
# Processing minute: 1437
# Current time: 24:57 on 1/1
# Dispatch logic at 24:57 on 1/1
# Processing minute: 1438
# Current time: 24:58 on 1/1
# Dispatch logic at 24:58 on 1/1
# Processing minute: 1439
# Current time: 24:59 on 1/1
# Dispatch logic at 24:59 on 1/1

# %%
taskings
# Out:
# [Task(order_id=12, robot_id=Togo, start_time=9:45),
#  Task(order_id=16, robot_id=Blackie, start_time=11:16),
#  Task(order_id=10, robot_id=Togo, start_time=11:50),
#  Task(order_id=15, robot_id=Fox, start_time=13:46),
#  Task(order_id=2, robot_id=Balto, start_time=17:50),
#  Task(order_id=14, robot_id=Blackie, start_time=19:0),
#  Task(order_id=3, robot_id=Fox, start_time=19:10),
#  Task(order_id=13, robot_id=Blackie, start_time=20:25),
#  Task(order_id=6, robot_id=Blackie, start_time=20:40)]
